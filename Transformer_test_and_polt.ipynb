# %%
# !unzip /content/contrast.zip -d /content
# Out:
# Archive:  /content/contrast.zip
#    creating: /content/contrast/algorithms/
#    creating: /content/contrast/algorithms/Traditional/
#   inflating: /content/contrast/algorithms/Traditional/ACO.py
#   inflating: /content/contrast/algorithms/Traditional/GA.py
#   inflating: /content/contrast/algorithms/Traditional/PSO.py
#    creating: /content/contrast/algorithms/Transformer/
#   inflating: /content/contrast/algorithms/Transformer/beamsearch-nb_nodes50-nb_TSPs10000-B2500.txt
#    creating: /content/contrast/algorithms/Transformer/checkpoint/
#   inflating: /content/contrast/algorithms/Transformer/checkpoint/checkpoint_21-03-01--17-09-47-n100-gpu0,1.pkl
#   inflating: /content/contrast/algorithms/Transformer/checkpoint/checkpoint_21-03-01--17-25-00-n50-gpu0.pkl
#   inflating: /content/contrast/algorithms/Transformer/environment_gpu.yml
#    creating: /content/contrast/algorithms/Transformer/pyconcorde/
#    creating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/
#  extracting: /content/contrast/algorithms/Transformer/pyconcorde/concorde/__init__.py
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/_concorde.pyx
#    creating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tests/
#  extracting: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tests/__init__.py
#    creating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tests/data/
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tests/data/berlin52.tsp
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tests/data_utils.py
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tests/test_concorde_core.py
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tests/test_concorde_datagroup.py
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/tsp.py
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/concorde/util.py
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/COPYING
#    creating: /content/contrast/algorithms/Transformer/pyconcorde/examples/
#  extracting: /content/contrast/algorithms/Transformer/pyconcorde/examples/requirements.txt
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/examples/us_state_capitals.png
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/examples/us_state_capitals.py
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/examples/us_state_capitals.tsv
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/MANIFEST.in
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/README.md
#  extracting: /content/contrast/algorithms/Transformer/pyconcorde/requirements.txt
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/setup.py
#    creating: /content/contrast/algorithms/Transformer/pyconcorde/tools/
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/tools/build_manylinux.sh
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/tools/install_edm_linux.sh
#   inflating: /content/contrast/algorithms/Transformer/pyconcorde/tools/install_edm_osx.sh
#   inflating: /content/contrast/algorithms/Transformer/test_tsp_transformer_beamsearch_TSP100.ipynb
#   inflating: /content/contrast/algorithms/Transformer/test_tsp_transformer_beamsearch_TSP50.ipynb
#   inflating: /content/contrast/algorithms/Transformer/train_tsp_transformer_TSP100.ipynb
#   inflating: /content/contrast/algorithms/Transformer/train_tsp_transformer_TSP50.ipynb
#   inflating: /content/contrast/algorithms/Transformer/Untitled2.ipynb
#   inflating: /content/contrast/algorithms/Transformer/visualization_TSP100.ipynb
#   inflating: /content/contrast/algorithms/Transformer/visualization_TSP50.ipynb
#    creating: /content/contrast/data/
#   inflating: /content/contrast/data/1000tsp100.pkl
#   inflating: /content/contrast/data/1000tsp20.pkl
#   inflating: /content/contrast/data/1000tsp50.pkl
#   inflating: /content/contrast/data/10k_TSP100.pt
#   inflating: /content/contrast/data/10k_TSP100_len.pt
#   inflating: /content/contrast/data/10k_TSP200.pt
#   inflating: /content/contrast/data/10k_TSP200_len.pt
#   inflating: /content/contrast/data/10k_TSP50.pt
#   inflating: /content/contrast/data/10k_TSP50_len.pt
#   inflating: /content/contrast/data/airport_100.py
#   inflating: /content/contrast/data/airport_20.py
#   inflating: /content/contrast/data/airport_50.py
#    creating: /content/contrast/data/data/
#   inflating: /content/contrast/data/data/tsp_visualization.png
#   inflating: /content/contrast/data/data/visual_friendly_tsp100.pkl
#   inflating: /content/contrast/data/data/visual_friendly_tsp20.pkl
#   inflating: /content/contrast/data/data/visual_friendly_tsp50.pkl

# %%
cd contrast/
# Out:
# /content/contrast

# %%
pwd
# Out:
# '/content/contrast'

# %%
ls
# Out:
# algorithms/  data/  pyconcorde/

# %%
import torch
import torch.nn as nn
import time
import argparse

import os
import datetime

from torch.distributions.categorical import Categorical

# %%
# visualization
# %matplotlib inline
from IPython.display import set_matplotlib_formats, clear_output
set_matplotlib_formats('png2x','pdf')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
try:
    import networkx as nx
    from scipy.spatial.distance import pdist, squareform
    from concorde.tsp import TSPSolver # !pip install -e pyconcorde
except:
    pass
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# <ipython-input-30-ae32d86b13cd>:4: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('png2x','pdf')

# %%
###################
# Hardware : CPU / GPU(s)
###################

device = torch.device("cpu");

print(torch.cuda.is_available())  # 输出应为True

# gpu_id = -1 # select CPU

gpu_id = '0' # select a single GPU
# gpu_id = '0,1' # select multiple GPUs
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)
if torch.cuda.is_available():
    device = torch.device("cuda")
    print('GPU name: {:s}, gpu_id: {:s}'.format(torch.cuda.get_device_name(0),gpu_id))

print(device)
# Out:
# True
# GPU name: Tesla T4, gpu_id: 0
# cuda

# %%
###################
# Hyper-parameters
###################

class DotDict(dict):
    def __init__(self, **kwds):
        self.update(kwds)
        self.__dict__ = self

args = DotDict()
args.nb_nodes = 20 # TSP20
args.nb_nodes = 50 # TSP50
# args.nb_nodes = 100 # TSP100
args.bsz = 512 # TSP20 TSP50
args.dim_emb = 128
args.dim_ff = 512
args.dim_input_nodes = 2
args.nb_layers_encoder = 6
args.nb_layers_decoder = 2
args.nb_heads = 8
args.nb_epochs = 10000
args.nb_batch_per_epoch = 2500
args.nb_batch_eval = 20
args.gpu_id = gpu_id
args.lr = 1e-4
args.tol = 1e-3
args.batchnorm = True  # if batchnorm=True  than batch norm is used
#args.batchnorm = False # if batchnorm=False than layer norm is used
args.max_len_PE = 1000

print(args)
# Out:
# {'nb_nodes': 50, 'bsz': 512, 'dim_emb': 128, 'dim_ff': 512, 'dim_input_nodes': 2, 'nb_layers_encoder': 6, 'nb_layers_decoder': 2, 'nb_heads': 8, 'nb_epochs': 10000, 'nb_batch_per_epoch': 2500, 'nb_batch_eval': 20, 'gpu_id': '0', 'lr': 0.0001, 'tol': 0.001, 'batchnorm': True, 'max_len_PE': 1000}

# %%
###################
# Network definition
# Notation :
#            bsz : batch size
#            nb_nodes : number of nodes/cities
#            dim_emb : embedding/hidden dimension
#            nb_heads : nb of attention heads
#            dim_ff : feed-forward dimension
#            nb_layers : number of encoder/decoder layers
###################
def compute_tour_length(x, tour):
    """
    Compute the length of a batch of tours
    Inputs : x of size (bsz, nb_nodes, 2) batch of tsp tour instances
             tour of size (bsz, nb_nodes) batch of sequences (node indices) of tsp tours
    Output : L of size (bsz,)             batch of lengths of each tsp tour
    """
    bsz = x.shape[0]
    nb_nodes = x.shape[1]
    arange_vec = torch.arange(bsz, device=x.device)
    first_cities = x[arange_vec, tour[:,0], :] # size(first_cities)=(bsz,2)
    previous_cities = first_cities
    L = torch.zeros(bsz, device=x.device)
    with torch.no_grad():
        for i in range(1,nb_nodes):
            current_cities = x[arange_vec, tour[:,i], :]
            L += torch.sum( (current_cities - previous_cities)**2 , dim=1 )**0.5 # dist(current, previous node)
            previous_cities = current_cities
        L += torch.sum( (current_cities - first_cities)**2 , dim=1 )**0.5 # dist(last, first node)
    return L


class Transformer_encoder_net(nn.Module):
    """
    Encoder network based on self-attention transformer
    Inputs :
      h of size      (bsz, nb_nodes+1, dim_emb)    batch of input cities
    Outputs :
      h of size      (bsz, nb_nodes+1, dim_emb)    batch of encoded cities
      score of size  (bsz, nb_nodes+1, nb_nodes+1) batch of attention scores
    """
    def __init__(self, nb_layers, dim_emb, nb_heads, dim_ff, batchnorm):
        super(Transformer_encoder_net, self).__init__()
        assert dim_emb == nb_heads* (dim_emb//nb_heads) # check if dim_emb is divisible by nb_heads
        self.MHA_layers = nn.ModuleList( [nn.MultiheadAttention(dim_emb, nb_heads) for _ in range(nb_layers)] )
        self.linear1_layers = nn.ModuleList( [nn.Linear(dim_emb, dim_ff) for _ in range(nb_layers)] )
        self.linear2_layers = nn.ModuleList( [nn.Linear(dim_ff, dim_emb) for _ in range(nb_layers)] )
        if batchnorm:
            self.norm1_layers = nn.ModuleList( [nn.BatchNorm1d(dim_emb) for _ in range(nb_layers)] )
            self.norm2_layers = nn.ModuleList( [nn.BatchNorm1d(dim_emb) for _ in range(nb_layers)] )
        else:
            self.norm1_layers = nn.ModuleList( [nn.LayerNorm(dim_emb) for _ in range(nb_layers)] )
            self.norm2_layers = nn.ModuleList( [nn.LayerNorm(dim_emb) for _ in range(nb_layers)] )
        self.nb_layers = nb_layers
        self.nb_heads = nb_heads
        self.batchnorm = batchnorm

    def forward(self, h):
        # PyTorch nn.MultiheadAttention requires input size (seq_len, bsz, dim_emb)
        h = h.transpose(0,1) # size(h)=(nb_nodes, bsz, dim_emb)
        # L layers
        for i in range(self.nb_layers):
            h_rc = h # residual connection, size(h_rc)=(nb_nodes, bsz, dim_emb)
            h, score = self.MHA_layers[i](h, h, h) # size(h)=(nb_nodes, bsz, dim_emb), size(score)=(bsz, nb_nodes, nb_nodes)
            # add residual connection
            h = h_rc + h # size(h)=(nb_nodes, bsz, dim_emb)
            if self.batchnorm:
                # Pytorch nn.BatchNorm1d requires input size (bsz, dim, seq_len)
                h = h.permute(1,2,0).contiguous() # size(h)=(bsz, dim_emb, nb_nodes)
                h = self.norm1_layers[i](h)       # size(h)=(bsz, dim_emb, nb_nodes)
                h = h.permute(2,0,1).contiguous() # size(h)=(nb_nodes, bsz, dim_emb)
            else:
                h = self.norm1_layers[i](h)       # size(h)=(nb_nodes, bsz, dim_emb)
            # feedforward
            h_rc = h # residual connection
            h = self.linear2_layers[i](torch.relu(self.linear1_layers[i](h)))
            h = h_rc + h # size(h)=(nb_nodes, bsz, dim_emb)
            if self.batchnorm:
                h = h.permute(1,2,0).contiguous() # size(h)=(bsz, dim_emb, nb_nodes)
                h = self.norm2_layers[i](h)       # size(h)=(bsz, dim_emb, nb_nodes)
                h = h.permute(2,0,1).contiguous() # size(h)=(nb_nodes, bsz, dim_emb)
            else:
                h = self.norm2_layers[i](h) # size(h)=(nb_nodes, bsz, dim_emb)
        # Transpose h
        h = h.transpose(0,1) # size(h)=(bsz, nb_nodes, dim_emb)
        return h, score

# %%
def myMHA(Q, K, V, nb_heads, mask=None, clip_value=None):
    """
    Compute multi-head attention (MHA) given a query Q, key K, value V and attention mask :
      h = Concat_{k=1}^nb_heads softmax(Q_k^T.K_k).V_k
    Note : We did not use nn.MultiheadAttention to avoid re-computing all linear transformations at each call.
    Inputs : Q of size (bsz, dim_emb, 1)                batch of queries
             K of size (bsz, dim_emb, nb_nodes+1)       batch of keys
             V of size (bsz, dim_emb, nb_nodes+1)       batch of values
             mask of size (bsz, nb_nodes+1)             batch of masks of visited cities
             clip_value is a scalar
    Outputs : attn_output of size (bsz, 1, dim_emb)     batch of attention vectors
              attn_weights of size (bsz, 1, nb_nodes+1) batch of attention weights
    """
    bsz, nb_nodes, emd_dim = K.size() #  dim_emb must be divisable by nb_heads
    if nb_heads>1:
        # PyTorch view requires contiguous dimensions for correct reshaping
        Q = Q.transpose(1,2).contiguous() # size(Q)=(bsz, dim_emb, 1)
        Q = Q.view(bsz*nb_heads, emd_dim//nb_heads, 1) # size(Q)=(bsz*nb_heads, dim_emb//nb_heads, 1)
        Q = Q.transpose(1,2).contiguous() # size(Q)=(bsz*nb_heads, 1, dim_emb//nb_heads)
        K = K.transpose(1,2).contiguous() # size(K)=(bsz, dim_emb, nb_nodes+1)
        K = K.view(bsz*nb_heads, emd_dim//nb_heads, nb_nodes) # size(K)=(bsz*nb_heads, dim_emb//nb_heads, nb_nodes+1)
        K = K.transpose(1,2).contiguous() # size(K)=(bsz*nb_heads, nb_nodes+1, dim_emb//nb_heads)
        V = V.transpose(1,2).contiguous() # size(V)=(bsz, dim_emb, nb_nodes+1)
        V = V.view(bsz*nb_heads, emd_dim//nb_heads, nb_nodes) # size(V)=(bsz*nb_heads, dim_emb//nb_heads, nb_nodes+1)
        V = V.transpose(1,2).contiguous() # size(V)=(bsz*nb_heads, nb_nodes+1, dim_emb//nb_heads)
    attn_weights = torch.bmm(Q, K.transpose(1,2))/ Q.size(-1)**0.5 # size(attn_weights)=(bsz*nb_heads, 1, nb_nodes+1)
    if clip_value is not None:
        attn_weights = clip_value * torch.tanh(attn_weights)
    if mask is not None:
        if nb_heads>1:
            mask = torch.repeat_interleave(mask, repeats=nb_heads, dim=0) # size(mask)=(bsz*nb_heads, nb_nodes+1)
        #attn_weights = attn_weights.masked_fill(mask.unsqueeze(1), float('-inf')) # size(attn_weights)=(bsz*nb_heads, 1, nb_nodes+1)
        attn_weights = attn_weights.masked_fill(mask.unsqueeze(1), float('-1e9')) # size(attn_weights)=(bsz*nb_heads, 1, nb_nodes+1)
    attn_weights = torch.softmax(attn_weights, dim=-1) # size(attn_weights)=(bsz*nb_heads, 1, nb_nodes+1)
    attn_output = torch.bmm(attn_weights, V) # size(attn_output)=(bsz*nb_heads, 1, dim_emb//nb_heads)
    if nb_heads>1:
        attn_output = attn_output.transpose(1,2).contiguous() # size(attn_output)=(bsz*nb_heads, dim_emb//nb_heads, 1)
        attn_output = attn_output.view(bsz, emd_dim, 1) # size(attn_output)=(bsz, dim_emb, 1)
        attn_output = attn_output.transpose(1,2).contiguous() # size(attn_output)=(bsz, 1, dim_emb)
        attn_weights = attn_weights.view(bsz, nb_heads, 1, nb_nodes) # size(attn_weights)=(bsz, nb_heads, 1, nb_nodes+1)
        attn_weights = attn_weights.mean(dim=1) # mean over the heads, size(attn_weights)=(bsz, 1, nb_nodes+1)
    return attn_output, attn_weights


class AutoRegressiveDecoderLayer(nn.Module):
    """
    Single decoder layer based on self-attention and query-attention
    Inputs :
      h_t of size      (bsz, 1, dim_emb)          batch of input queries
      K_att of size    (bsz, nb_nodes+1, dim_emb) batch of query-attention keys
      V_att of size    (bsz, nb_nodes+1, dim_emb) batch of query-attention values
      mask of size     (bsz, nb_nodes+1)          batch of masks of visited cities
    Output :
      h_t of size (bsz, nb_nodes+1)               batch of transformed queries
    """
    def __init__(self, dim_emb, nb_heads):
        super(AutoRegressiveDecoderLayer, self).__init__()
        self.dim_emb = dim_emb
        self.nb_heads = nb_heads
        self.Wq_selfatt = nn.Linear(dim_emb, dim_emb)
        self.Wk_selfatt = nn.Linear(dim_emb, dim_emb)
        self.Wv_selfatt = nn.Linear(dim_emb, dim_emb)
        self.W0_selfatt = nn.Linear(dim_emb, dim_emb)
        self.W0_att = nn.Linear(dim_emb, dim_emb)
        self.Wq_att = nn.Linear(dim_emb, dim_emb)
        self.W1_MLP = nn.Linear(dim_emb, dim_emb)
        self.W2_MLP = nn.Linear(dim_emb, dim_emb)
        self.BN_selfatt = nn.LayerNorm(dim_emb)
        self.BN_att = nn.LayerNorm(dim_emb)
        self.BN_MLP = nn.LayerNorm(dim_emb)
        self.K_sa = None
        self.V_sa = None

    def reset_selfatt_keys_values(self):
        self.K_sa = None
        self.V_sa = None

    # For beam search
    def reorder_selfatt_keys_values(self, t, idx_top_beams):
        bsz, B = idx_top_beams.size()
        zero_to_B = torch.arange(B, device=idx_top_beams.device) # [0,1,...,B-1]
        B2 = self.K_sa.size(0)// bsz
        self.K_sa = self.K_sa.view(bsz, B2, t+1, self.dim_emb) # size(self.K_sa)=(bsz, B2, t+1, dim_emb)
        K_sa_tmp = self.K_sa.clone()
        self.K_sa = torch.zeros(bsz, B, t+1, self.dim_emb, device=idx_top_beams.device)
        for b in range(bsz):
            self.K_sa[b, zero_to_B, :, :] = K_sa_tmp[b, idx_top_beams[b], :, :]
        self.K_sa = self.K_sa.view(bsz*B, t+1, self.dim_emb) # size(self.K_sa)=(bsz*B, t+1, dim_emb)
        self.V_sa = self.V_sa.view(bsz, B2, t+1, self.dim_emb) # size(self.K_sa)=(bsz, B, t+1, dim_emb)
        V_sa_tmp = self.V_sa.clone()
        self.V_sa = torch.zeros(bsz, B, t+1, self.dim_emb, device=idx_top_beams.device)
        for b in range(bsz):
            self.V_sa[b, zero_to_B, :, :] = V_sa_tmp[b, idx_top_beams[b], :, :]
        self.V_sa = self.V_sa.view(bsz*B, t+1, self.dim_emb) # size(self.K_sa)=(bsz*B, t+1, dim_emb)

    # For beam search
    def repeat_selfatt_keys_values(self, B):
        self.K_sa = torch.repeat_interleave(self.K_sa, B, dim=0) # size(self.K_sa)=(bsz.B, t+1, dim_emb)
        self.V_sa = torch.repeat_interleave(self.V_sa, B, dim=0) # size(self.K_sa)=(bsz.B, t+1, dim_emb)

    def forward(self, h_t, K_att, V_att, mask):
        bsz = h_t.size(0)
        h_t = h_t.view(bsz,1,self.dim_emb) # size(h_t)=(bsz, 1, dim_emb)
        # embed the query for self-attention
        q_sa = self.Wq_selfatt(h_t) # size(q_sa)=(bsz, 1, dim_emb)
        k_sa = self.Wk_selfatt(h_t) # size(k_sa)=(bsz, 1, dim_emb)
        v_sa = self.Wv_selfatt(h_t) # size(v_sa)=(bsz, 1, dim_emb)
        # concatenate the new self-attention key and value to the previous keys and values
        if self.K_sa is None:
            self.K_sa = k_sa # size(self.K_sa)=(bsz, 1, dim_emb)
            self.V_sa = v_sa # size(self.V_sa)=(bsz, 1, dim_emb)
        else:
            self.K_sa = torch.cat([self.K_sa, k_sa], dim=1)
            self.V_sa = torch.cat([self.V_sa, v_sa], dim=1)
        # compute self-attention between nodes in the partial tour
        h_t = h_t + self.W0_selfatt( myMHA(q_sa, self.K_sa, self.V_sa, self.nb_heads)[0] ) # size(h_t)=(bsz, 1, dim_emb)
        h_t = self.BN_selfatt(h_t.squeeze()) # size(h_t)=(bsz, dim_emb)
        h_t = h_t.view(bsz, 1, self.dim_emb) # size(h_t)=(bsz, 1, dim_emb)
        # compute attention between self-attention nodes and encoding nodes in the partial tour (translation process)
        q_a = self.Wq_att(h_t) # size(q_a)=(bsz, 1, dim_emb)
        h_t = h_t + self.W0_att( myMHA(q_a, K_att, V_att, self.nb_heads, mask)[0] ) # size(h_t)=(bsz, 1, dim_emb)
        h_t = self.BN_att(h_t.squeeze()) # size(h_t)=(bsz, dim_emb)
        h_t = h_t.view(bsz, 1, self.dim_emb) # size(h_t)=(bsz, 1, dim_emb)
        # MLP
        h_t = h_t + self.W2_MLP(torch.relu(self.W1_MLP(h_t)))
        h_t = self.BN_MLP(h_t.squeeze(1)) # size(h_t)=(bsz, dim_emb)
        return h_t


class Transformer_decoder_net(nn.Module):
    """
    Decoder network based on self-attention and query-attention transformers
    Inputs :
      h_t of size      (bsz, 1, dim_emb)                            batch of input queries
      K_att of size    (bsz, nb_nodes+1, dim_emb*nb_layers_decoder) batch of query-attention keys for all decoding layers
      V_att of size    (bsz, nb_nodes+1, dim_emb*nb_layers_decoder) batch of query-attention values for all decoding layers
      mask of size     (bsz, nb_nodes+1)                            batch of masks of visited cities
    Output :
      prob_next_node of size (bsz, nb_nodes+1)                      batch of probabilities of next node
    """
    def __init__(self, dim_emb, nb_heads, nb_layers_decoder):
        super(Transformer_decoder_net, self).__init__()
        self.dim_emb = dim_emb
        self.nb_heads = nb_heads
        self.nb_layers_decoder = nb_layers_decoder
        self.decoder_layers = nn.ModuleList( [AutoRegressiveDecoderLayer(dim_emb, nb_heads) for _ in range(nb_layers_decoder-1)] )
        self.Wq_final = nn.Linear(dim_emb, dim_emb)

    # Reset to None self-attention keys and values when decoding starts
    def reset_selfatt_keys_values(self):
        for l in range(self.nb_layers_decoder-1):
            self.decoder_layers[l].reset_selfatt_keys_values()

    # For beam search
    def reorder_selfatt_keys_values(self, t, idx_top_beams):
        for l in range(self.nb_layers_decoder-1):
            self.decoder_layers[l].reorder_selfatt_keys_values(t, idx_top_beams)

    # For beam search
    def repeat_selfatt_keys_values(self, B):
        for l in range(self.nb_layers_decoder-1):
            self.decoder_layers[l].repeat_selfatt_keys_values(B)

    def forward(self, h_t, K_att, V_att, mask):
        for l in range(self.nb_layers_decoder):
            K_att_l = K_att[:,:,l*self.dim_emb:(l+1)*self.dim_emb].contiguous()  # size(K_att_l)=(bsz, nb_nodes+1, dim_emb)
            V_att_l = V_att[:,:,l*self.dim_emb:(l+1)*self.dim_emb].contiguous()  # size(V_att_l)=(bsz, nb_nodes+1, dim_emb)
            if l<self.nb_layers_decoder-1: # decoder layers with multiple heads (intermediate layers)
                h_t = self.decoder_layers[l](h_t, K_att_l, V_att_l, mask)
            else: # decoder layers with single head (final layer)
                q_final = self.Wq_final(h_t)
                bsz = h_t.size(0)
                q_final = q_final.view(bsz, 1, self.dim_emb)
                attn_weights = myMHA(q_final, K_att_l, V_att_l, 1, mask, 10)[1]
        prob_next_node = attn_weights.squeeze(1)
        return prob_next_node


def generate_positional_encoding(d_model, max_len):
    """
    Create standard transformer PEs.
    Inputs :
      d_model is a scalar correspoding to the hidden dimension
      max_len is the maximum length of the sequence
    Output :
      pe of size (max_len, d_model), where d_model=dim_emb, max_len=1000
    """
    pe = torch.zeros(max_len, d_model)
    position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
    pe[:,0::2] = torch.sin(position * div_term)
    pe[:,1::2] = torch.cos(position * div_term)
    return pe


class TSP_net(nn.Module):
    """
    The TSP network is composed of two steps :
      Step 1. Encoder step : Take a set of 2D points representing a fully connected graph
                             and encode the set with self-transformer.
      Step 2. Decoder step : Build the TSP tour recursively/autoregressively,
                             i.e. one node at a time, with a self-transformer and query-transformer.
    Inputs :
      x of size (bsz, nb_nodes, dim_emb) Euclidian coordinates of the nodes/cities
      deterministic is a boolean : If True the salesman will chose the city with highest probability.
                                   If False the salesman will chose the city with Bernouilli sampling.
    Outputs :
      tours of size (bsz, nb_nodes) : batch of tours, i.e. sequences of ordered cities
                                      tours[b,t] contains the idx of the city visited at step t in batch b
      sumLogProbOfActions of size (bsz,) : batch of sum_t log prob( pi_t | pi_(t-1),...,pi_0 )
    """

    def __init__(self, dim_input_nodes, dim_emb, dim_ff, nb_layers_encoder, nb_layers_decoder, nb_heads, max_len_PE,
                 batchnorm=True):
        super(TSP_net, self).__init__()

        self.dim_emb = dim_emb

        # input embedding layer
        self.input_emb = nn.Linear(dim_input_nodes, dim_emb)

        # encoder layer
        self.encoder = Transformer_encoder_net(nb_layers_encoder, dim_emb, nb_heads, dim_ff, batchnorm)

        # vector to start decoding
        self.start_placeholder = nn.Parameter(torch.randn(dim_emb))

        # decoder layer
        self.decoder = Transformer_decoder_net(dim_emb, nb_heads, nb_layers_decoder)
        self.WK_att_decoder = nn.Linear(dim_emb, nb_layers_decoder* dim_emb)
        self.WV_att_decoder = nn.Linear(dim_emb, nb_layers_decoder* dim_emb)
        self.PE = generate_positional_encoding(dim_emb, max_len_PE)

    def forward(self, x, B, greedy, beamsearch):

        # some parameters
        bsz = x.shape[0]
        nb_nodes = x.shape[1]
        zero_to_bsz = torch.arange(bsz, device=x.device) # [0,1,...,bsz-1]

        # For beam search
        zero_to_B = torch.arange(B, device=x.device) # [0,1,...,B-1]

        # input embedding layer
        h = self.input_emb(x) # size(h)=(bsz, nb_nodes, dim_emb)

        # concat the nodes and the input placeholder that starts the decoding
        h = torch.cat([h, self.start_placeholder.repeat(bsz, 1, 1)], dim=1) # size(start_placeholder)=(bsz, nb_nodes+1, dim_emb)

        # encoder layer
        h_encoder, _ = self.encoder(h) # size(h)=(bsz, nb_nodes+1, dim_emb)

        # key and value for decoder
        K_att_decoder = self.WK_att_decoder(h_encoder) # size(K_att)=(bsz, nb_nodes+1, dim_emb*nb_layers_decoder)
        V_att_decoder = self.WV_att_decoder(h_encoder) # size(V_att)=(bsz, nb_nodes+1, dim_emb*nb_layers_decoder)

        # starting node in tour
        self.PE = self.PE.to(x.device)

        # For beam search
        tours_greedy = torch.zeros(2, nb_nodes, device=x.device)
        tours_beamsearch = torch.zeros(2, nb_nodes, device=x.device)
        scores_greedy = torch.zeros(2, device=x.device)
        scores_beamsearch = torch.zeros(2, device=x.device)

        # Greedy search
        if greedy:
            #print('Greedy decoding')
            deterministic = True
            # list that will contain Long tensors of shape (bsz,) that gives the idx of the cities chosen at time t
            tours = []
            # list that will contain Float tensors of shape (bsz,) that gives the neg log probs of the choices made at time t
            sumLogProbOfActions = []
            # input placeholder that starts the decoding
            idx_start_placeholder = torch.Tensor([nb_nodes]).long().repeat(bsz).to(x.device)
            h_start = h_encoder[zero_to_bsz, idx_start_placeholder, :] + self.PE[0].repeat(bsz,1) # size(h_start)=(bsz, dim_emb)
            # initialize mask of visited cities
            mask_visited_nodes = torch.zeros(bsz, nb_nodes+1, device=x.device).bool() # False
            mask_visited_nodes[zero_to_bsz, idx_start_placeholder] = True
            # clear key and val stored in the decoder
            self.decoder.reset_selfatt_keys_values()
            # construct tour recursively
            h_t = h_start
            for t in range(nb_nodes):
                # compute probability over the next node in the tour
                prob_next_node = self.decoder(h_t, K_att_decoder, V_att_decoder, mask_visited_nodes) # size(prob_next_node)=(bsz, nb_nodes+1)
                # choose node with highest probability or sample with Bernouilli
                if deterministic:
                    idx = torch.argmax(prob_next_node, dim=1) # size(query)=(bsz,)
                else:
                    idx = Categorical(prob_next_node).sample() # size(query)=(bsz,)
                # compute logprobs of the action items in the list sumLogProbOfActions
                ProbOfChoices = prob_next_node[zero_to_bsz, idx]
                sumLogProbOfActions.append( torch.log(ProbOfChoices) )  # size(query)=(bsz,)
                # update embedding of the current visited node
                h_t = h_encoder[zero_to_bsz, idx, :] # size(h_start)=(bsz, dim_emb)
                h_t = h_t + self.PE[t+1].expand(bsz, self.dim_emb)
                # update tour
                tours.append(idx)
                # update masks with visited nodes
                mask_visited_nodes = mask_visited_nodes.clone()
                mask_visited_nodes[zero_to_bsz, idx] = True
            # logprob_of_choices = sum_t log prob( pi_t | pi_(t-1),...,pi_0 )
            sumLogProbOfActions = torch.stack(sumLogProbOfActions,dim=1).sum(dim=1) # size(sumLogProbOfActions)=(bsz,)
            # convert the list of nodes into a tensor of shape (bsz,num_cities)
            tours = torch.stack(tours,dim=1) # size(col_index)=(bsz, nb_nodes)
            tours_greedy = tours
            scores_greedy = sumLogProbOfActions

        # Beamsearch
        if beamsearch:
            #print('Beam search decoding')
            # clear key and val stored in the decoder
            self.decoder.reset_selfatt_keys_values()
            K_att_decoder_tmp = K_att_decoder # size(K_att_decoder_tmp)=(bsz, nb_nodes, dim_emb*nb_layers_decoder)
            V_att_decoder_tmp = V_att_decoder # size(V_att_decoder_tmp)=(bsz, nb_nodes, dim_emb*nb_layers_decoder)
            for t in range(nb_nodes):
                #if not t%10:
                #    print('t: {}, GPU reserved mem: {:.2f}, GPU allocated mem: {:.2f}'.format(t,torch.cuda.memory_reserved(0)/1e9,torch.cuda.memory_allocated(0)/1e9))
                if t==0: # at t=0, there are at most B_{t=0}=nb_nodes beams
                    B_t0 = min(B, nb_nodes)
                    # input placeholder that starts the decoding
                    idx_start_placeholder = torch.Tensor([nb_nodes]).long().repeat(bsz).to(x.device)
                    h_start = h_encoder[zero_to_bsz, idx_start_placeholder, :] + self.PE[0].repeat(bsz,1) # size(h_start)=(bsz, dim_emb)
                    h_t = h_start # size(h_start)=(bsz, dim_emb)
                    mask_visited_nodes = torch.zeros(bsz, nb_nodes+1, device=x.device).bool() # False, size(mask_visited_nodes)=(bsz, nb_nodes+1) # initialize mask of visited cities
                    mask_visited_nodes[zero_to_bsz, idx_start_placeholder] = True
                    # compute probability over the next node in the tour
                    prob_next_node = self.decoder(h_t, K_att_decoder, V_att_decoder, mask_visited_nodes) # size(prob_next_node)=(bsz, nb_nodes+1)
                    # compute score_t + sum_t score_{t-1} for all beams
                    score_t = torch.log(prob_next_node) # size(score_t)=(bsz, nb_nodes+1) for t=0
                    sum_scores = score_t # size(score_t)=(bsz, nb_nodes+1)
                    # choose nodes with top-B sumScores
                    top_val, top_idx = torch.topk(sum_scores, B_t0, dim=1) # size(sumScores)=(bsz, B_t0)
                    # update sum_t score_{t} for all beams
                    sum_scores = top_val # size(sumScores)=(bsz, B_t0)
                    zero_to_B_t0 = torch.arange(B_t0, device=x.device) # [0,1,...,B_t0-1]
                    mask_visited_nodes = mask_visited_nodes.unsqueeze(1) # size(mask_visited_nodes)=(bsz, 1, nb_nodes+1)
                    mask_visited_nodes = torch.repeat_interleave(mask_visited_nodes, B_t0, dim=1)
                    for b in range(bsz):
                        mask_visited_nodes[b, zero_to_B_t0, top_idx[b]] = True # size(mask_visited_nodes)=(bsz, B_t0, nb_nodes+1)
                    tours = torch.zeros(bsz, B_t0, nb_nodes, device=x.device).long() # size(tours)=(bsz, B_t0, nb_nodes)
                    tours[:,:,t] = top_idx # size(tours)=(bsz, B_t0, nb_nodes)
                    # update embedding of the current visited node
                    h_t = torch.zeros(bsz, B_t0, self.dim_emb, device=x.device) # size(tours)=(bsz, B_t0, dim_emb)
                    for b in range(bsz):
                        h_t[b, :, :] = h_encoder[b, top_idx[b], :] # size(h_t)=(bsz, B_t0, dim_emb)
                    h_t = h_t + self.PE[t+1].expand(bsz, B_t0, self.dim_emb) # size(h_t)=(bsz, B_t0, dim_emb)
                    self.decoder.repeat_selfatt_keys_values(B_t0)
                    K_att_decoder = torch.repeat_interleave(K_att_decoder_tmp, B_t0, dim=0) # size(K_att_decoder)=(bsz*B_t0, nb_nodes+1, dim_emb*nb_layers_decoder)
                    V_att_decoder = torch.repeat_interleave(V_att_decoder_tmp, B_t0, dim=0) # size(V_att_decoder)=(bsz*B_t0, nb_nodes+1, dim_emb*nb_layers_decoder)

                elif t==1: # at t=1, there are at most B_{t=1}=nb_nodes^2 beams
                    # compute probability over the next node in the tour
                    h_t = h_t.view(bsz*B_t0, self.dim_emb)
                    mask_visited_nodes = mask_visited_nodes.view(bsz*B_t0, nb_nodes+1)
                    prob_next_node = self.decoder(h_t, K_att_decoder, V_att_decoder, mask_visited_nodes) # size(prob_next_node)=(bsz.B_t0, nb_nodes+1)
                    prob_next_node = prob_next_node.view(bsz, B_t0, nb_nodes+1) # size(prob_next_node)=(bsz, B_t0, nb_nodes+1)
                    mask_visited_nodes = mask_visited_nodes.view(bsz, B_t0, nb_nodes+1)
                    h_t = h_t.view(bsz, B_t0, self.dim_emb)
                    # compute score_t + sum_t score_{t-1} for all beams
                    score_t = torch.log(prob_next_node) # size(score_t)=(bsz, B, nb_nodes+1)
                    sum_scores = score_t + sum_scores.unsqueeze(2) # size(score_t)=(bsz, B, nb_nodes+1)
                    sum_scores_flatten = sum_scores.view(bsz, -1) # size(sumScores_next_node)=(bsz, B.(nb_nodes+1))
                    # choose nodes with top-B sumScores
                    top_val, top_idx = torch.topk(sum_scores_flatten, B, dim=1)
                    idx_top_beams = top_idx // (nb_nodes+1) # size(idx_beam_topB)=(bsz, B)
                    idx_in_beams = top_idx - idx_top_beams* (nb_nodes+1) # size(idx_in_beams)=(bsz, B)
                    # update sum_t score_{t} for all beams
                    sum_scores = top_val
                    # update beam masks with visited nodes
                    mask_visited_nodes_tmp = mask_visited_nodes.clone() # size(mask_visited_nodes_tmp)=(bsz, B_t0, nb_nodes+1)
                    mask_visited_nodes = torch.zeros(bsz, B, nb_nodes+1, device=x.device).bool() # size(mask_visited_nodes)=(bsz, B, nb_nodes+1)
                    for b in range(bsz):
                        mask_visited_nodes[b, zero_to_B, :] = mask_visited_nodes_tmp[b, idx_top_beams[b], :] # size(mask_visited_nodes)=(bsz, B, nb_nodes+1)
                    for b in range(bsz):
                        mask_visited_nodes[b, zero_to_B, idx_in_beams[b]] = True # size(mask_visited_nodes)=(bsz, B, nb_nodes+1)
                    # update beam tours with visited nodes
                    tours_tmp = tours.clone()
                    tours = torch.zeros(bsz, B, nb_nodes, device=x.device).long() # size(tours)=(bsz, B, nb_nodes)
                    for b in range(bsz):
                        tours[b, zero_to_B, :] = tours_tmp[b, idx_top_beams[b], :]
                    tours[:,:,t] = idx_in_beams # size(tours)=(bsz, B, nb_nodes)
                    # update embedding of the current visited node
                    h_t = torch.zeros(bsz, B, self.dim_emb, device=x.device) # size(tours)=(bsz, B_t0, dim_emb)
                    for b in range(bsz):
                        h_t[b, :, :] = h_encoder[b, idx_in_beams[b], :] # size(h_t)=(bsz, B, dim_emb)
                    h_t = h_t + self.PE[t+1].expand(bsz, B, self.dim_emb) # size(h_t)=(bsz, B, dim_emb)
                    # update self-attention embeddings of partial tours
                    self.decoder.reorder_selfatt_keys_values(t, idx_top_beams) # size(K_att_decoder)=(bsz*B_t0, nb_nodes+1, dim_emb*nb_layers_decoder)
                    K_att_decoder = torch.repeat_interleave(K_att_decoder_tmp, B, dim=0) # size(K_att_decoder)=(bsz*B, nb_nodes+1, dim_emb*nb_layers_decoder)
                    V_att_decoder = torch.repeat_interleave(V_att_decoder_tmp, B, dim=0) # size(V_att_decoder)=(bsz*B, nb_nodes+1, dim_emb*nb_layers_decoder)

                else: # at t>=2, we arbitrary decide to have at most B_{t>=2}=nb_nodes^2 beams
                    # compute probability over the next node in the tour
                    h_t = h_t.view(bsz*B, self.dim_emb)
                    mask_visited_nodes = mask_visited_nodes.view(bsz*B, nb_nodes+1)
                    prob_next_node = self.decoder(h_t, K_att_decoder, V_att_decoder, mask_visited_nodes) # size(prob_next_node)=(bsz.B, nb_nodes+1)
                    prob_next_node = prob_next_node.view(bsz, B, nb_nodes+1) # size(prob_next_node)=(bsz, B, nb_nodes+1)
                    mask_visited_nodes = mask_visited_nodes.view(bsz, B, nb_nodes+1)
                    h_t = h_t.view(bsz, B, self.dim_emb)
                    # compute score_t + sum_t score_{t-1} for all beams
                    score_t = torch.log(prob_next_node) # size(score_t)=(bsz, B, nb_nodes+1)
                    sum_scores = score_t + sum_scores.unsqueeze(2) # size(score_t)=(bsz, B, nb_nodes+1)
                    sum_scores_flatten = sum_scores.view(bsz, -1) # size(sumScores_next_node)=(bsz, B.(nb_nodes+1))
                    # choose nodes with top-B sumScores
                    top_val, top_idx = torch.topk(sum_scores_flatten, B, dim=1)
                    idx_top_beams = top_idx // (nb_nodes+1) # size(idx_beam_topB)=(bsz, B)
                    idx_in_beams = top_idx - idx_top_beams* (nb_nodes+1) # size(idx_in_beams)=(bsz, B)
                    # update sum_t score_{t} for all beams
                    sum_scores = top_val
                    # update beam masks with visited nodes
                    mask_visited_nodes_tmp = mask_visited_nodes.clone()
                    for b in range(bsz):
                        mask_visited_nodes[b, zero_to_B, :] = mask_visited_nodes_tmp[b, idx_top_beams[b], :]
                    for b in range(bsz):
                        mask_visited_nodes[b, zero_to_B, idx_in_beams[b]] = True
                    # update beam tours with visited nodes
                    tours_tmp = tours.clone()
                    for b in range(bsz):
                        tours[b, zero_to_B, :] = tours_tmp[b, idx_top_beams[b], :]
                    tours[:,:,t] = idx_in_beams # size(tours)=(bsz, B, nb_nodes)
                    # update embedding of the current visited node
                    for b in range(bsz):
                        h_t[b, :, :] = h_encoder[b, idx_in_beams[b], :] # size(h_t)=(bsz, B, dim_emb)
                    h_t = h_t + self.PE[t+1].expand(bsz, B, self.dim_emb) # size(h_t)=(bsz, B, dim_emb)
                    # update self-attention embeddings of partial tours
                    self.decoder.reorder_selfatt_keys_values(t, idx_top_beams)
            # sum_t log prob( pi_t | pi_0,...pi_(t-1) )
            sum_scores = sum_scores[:,0] # size(sumScores)=(bsz)
            tours_beamsearch = tours
            scores_beamsearch = sum_scores

        return tours_greedy, tours_beamsearch, scores_greedy, scores_beamsearch

# %%
###################
# Instantiate a training network and a baseline network
###################
try:
    del model_baseline # remove existing model
except:
    pass

model_baseline = TSP_net(args.dim_input_nodes, args.dim_emb, args.dim_ff,
              args.nb_layers_encoder, args.nb_layers_decoder, args.nb_heads, args.max_len_PE,
              batchnorm=args.batchnorm)

# # uncomment these lines if trained with multiple GPUs
# print(torch.cuda.device_count())
# if torch.cuda.device_count()>1:
#     model_baseline = nn.DataParallel(model_baseline)
# # uncomment these lines if trained with multiple GPUs

model_baseline = model_baseline.to(device)
model_baseline.eval()

print(args); print('')
# Out:
# {'nb_nodes': 50, 'bsz': 512, 'dim_emb': 128, 'dim_ff': 512, 'dim_input_nodes': 2, 'nb_layers_encoder': 6, 'nb_layers_decoder': 2, 'nb_heads': 8, 'nb_epochs': 10000, 'nb_batch_per_epoch': 2500, 'nb_batch_eval': 20, 'gpu_id': '0', 'lr': 0.0001, 'tol': 0.001, 'batchnorm': True, 'max_len_PE': 1000}

# %%
###################
# Load checkpoint
###################
checkpoint_file = "algorithms/Transformer/checkpoint/checkpoint_21-03-01--17-25-00-n50-gpu0.pkl"
checkpoint = torch.load(checkpoint_file, map_location=device)
epoch_ckpt = checkpoint['epoch'] + 1
tot_time_ckpt = checkpoint['tot_time']
plot_performance_train = checkpoint['plot_performance_train']
plot_performance_baseline = checkpoint['plot_performance_baseline']
model_baseline.load_state_dict(checkpoint['model_baseline'])
print('Load checkpoint file={:s}\n  Checkpoint at epoch= {:d} and time={:.3f}min\n'.format(checkpoint_file,epoch_ckpt-1,tot_time_ckpt/60))
del checkpoint

mystring_min = 'Epoch: {:d}, tot_time_ckpt: {:.3f}day, L_train: {:.3f}, L_base: {:.3f}\n'.format(
    epoch_ckpt, tot_time_ckpt/3660/24, plot_performance_train[-1][1], plot_performance_baseline[-1][1])
print(mystring_min)
# Out:
# Load checkpoint file=algorithms/Transformer/checkpoint/checkpoint_21-03-01--17-25-00-n50-gpu0.pkl
#   Checkpoint at epoch= 1623 and time=30080.135min
#
# Epoch: 1624, tot_time_ckpt: 20.547day, L_train: 5.707, L_base: 5.705

# %%
###################
# Hyper-parameter for beam search
###################

# experiment n50
args.nb_nodes = 50
# B = 1; args.bsz = 10000; greedy = True; beamsearch = False # greedy
# B = 100; args.bsz = 250; greedy = False; beamsearch = True
# B = 1000; args.bsz = 25; greedy = False; beamsearch = True
# B = 2500; args.bsz = 10; greedy = False; beamsearch = True
B = 2500; args.bsz = 10; greedy = False; beamsearch = True
args.nb_batch_eval = (10000+args.bsz-1)// args.bsz
print('nb_nodes: {}, bsz: {}, B: {}, nb_batch_eval: {}, tot TSPs: {}\n'.format(args.nb_nodes, args.bsz, B, args.nb_batch_eval, args.nb_batch_eval* args.bsz))

# # experiment n100
# args.nb_nodes = 100
# B = 1; args.bsz = 5000; greedy = True; beamsearch = False # greedy
# B = 1000; args.bsz = 10; greedy = False; beamsearch = True
# args.nb_batch_eval = (10000+args.bsz-1)// args.bsz
# print('nb_nodes: {}, bsz: {}, B: {}, nb_batch_eval: {}, tot TSPs: {}\n'.format(args.nb_nodes, args.bsz, B, args.nb_batch_eval, args.nb_batch_eval* args.bsz))
# Out:
# nb_nodes: 50, bsz: 10, B: 2500, nb_batch_eval: 1000, tot TSPs: 10000

# %%
from concorde.tsp import TSPSolver
print("Concorde 安装成功！")
# Out:
# Concorde 安装成功！

# %%
pwd
# Out:
# '/content/contrast'

# %%
def generate_tsp_dataset(save_path, num_instances=10000, num_nodes=50, scale=750):
    """生成带Concorde最优解的数据集"""
    # 生成随机坐标
    coords = torch.rand(num_instances, num_nodes, 2) * scale

    # 计算每个实例的Concorde最优解
    optimal_lengths = []
    for i in range(num_instances):
        # 调用Concorde求解器
        solver = TSPSolver.from_data(coords[i,:,0].numpy(),
                                   coords[i,:,1].numpy(),
                                   norm="EUC_2D")
        solution = solver.solve()
        optimal_lengths.append(solution.optimal_value)

    # 保存数据
    torch.save({
        'x': coords,
        'optimal_lengths': torch.tensor(optimal_lengths)
    }, f"{save_path}.pkl")

generate_tsp_dataset(
    save_path="data/visual_friendly_withlen10k_tsp50",
    num_instances=10000,
    num_nodes=50,
    scale=750
)

# %%
print('nb_nodes: {}, bsz: {}, B: {}, nb_batch_eval: {}, tot TSPs: {}\n'.format(args.nb_nodes, args.bsz, B, args.nb_batch_eval, args.nb_batch_eval* args.bsz))
# Out:
# nb_nodes: 50, bsz: 25, B: 200, nb_batch_eval: 40, tot TSPs: 1000

# %%
###################
# Test set
###################
if args.nb_nodes == 50:
    # x_10k = torch.load('data/10k_TSP50.pt').to(device)
    # x_10k_len = torch.load('data/10k_TSP50_len.pt').to(device)
    # L_concorde = x_10k_len.mean().item()
    # 加载新的测试集
    data = torch.load('data/visual_friendly_withlen10k_tsp50.pkl', map_location=device)

    # 提取数据
    x_10k = data['x'].to(device)                   # 形状 (num_samples, 50, 2)
    x_10k_len = data['optimal_lengths'].to(device) # 形状 (num_samples,)

    # 动态调整参数
    total_samples = x_10k.size(0)
    args.nb_batch_eval = (total_samples + args.bsz - 1) // args.bsz
    nb_TSPs = total_samples

    L_concorde = x_10k_len.mean().item()
    print(f'Loaded {total_samples} TSP50 instances, Concorde avg length: {L_concorde:.2f}')
if args.nb_nodes == 100:
    x_10k = torch.load('data/10k_TSP100.pt').to(device)
    x_10k_len = torch.load('data/10k_TSP100_len.pt').to(device)
    L_concorde = x_10k_len.mean().item()
nb_TSPs = args.nb_batch_eval* args.bsz
# Out:
# Loaded 10000 TSP50 instances, Concorde avg length: 4270.65

# %%
print('nb_nodes: {}, bsz: {}, B: {}, nb_batch_eval: {}, tot TSPs: {}\n'.format(args.nb_nodes, args.bsz, B, args.nb_batch_eval, args.nb_batch_eval* args.bsz))
# Out:
# nb_nodes: 50, bsz: 10, B: 2500, nb_batch_eval: 1000, tot TSPs: 10000

# %%
# 优化方案2（安全模式）
B = 500; args.bsz = 5    # 显存需求 4.2GB

# 更新批次计算
total_samples = x_10k.size(0)
args.nb_batch_eval = (total_samples + args.bsz -1) // args.bsz  # 动态计算

# %%
print('nb_nodes: {}, bsz: {}, B: {}, nb_batch_eval: {}, tot TSPs: {}\n'.format(args.nb_nodes, args.bsz, B, args.nb_batch_eval, args.nb_batch_eval* args.bsz))
# Out:
# nb_nodes: 50, bsz: 5, B: 500, nb_batch_eval: 2000, tot TSPs: 10000

# %%
###################
# Run beam search
###################
start = time.time()
mean_tour_length_greedy = 0
mean_tour_length_beamsearch = 0
mean_scores_greedy = 0
mean_scores_beamsearch = 0
gap_greedy = 0
gap_beamsearch = 0
print(args.nb_batch_eval)
for step in range(0,args.nb_batch_eval):
    print('batch index: {}, tot_time: {:.3f}min'.format(step, (time.time()-start)/60))
    # extract a batch of test tsp instances
    x = x_10k[step*args.bsz:(step+1)*args.bsz,:,:]
    x_len_concorde = x_10k_len[step*args.bsz:(step+1)*args.bsz]
    # compute tour for model and baseline
    with torch.no_grad():
        tours_greedy, tours_beamsearch, scores_greedy, scores_beamsearch = model_baseline(x, B, greedy, beamsearch)
        # greedy
        if greedy:
            L_greedy = compute_tour_length(x, tours_greedy)
            mean_tour_length_greedy += L_greedy.mean().item()
            mean_scores_greedy += scores_greedy.mean().item()
            x_len_greedy = L_greedy
            gap_greedy += (x_len_greedy/ x_len_concorde - 1.0).sum()
        # beamsearch
        if beamsearch:
            tours_beamsearch = tours_beamsearch.view(args.bsz*B, args.nb_nodes)
            x = x.repeat_interleave(B,dim=0)
            L_beamsearch = compute_tour_length(x, tours_beamsearch)
            tours_beamsearch = tours_beamsearch.view(args.bsz, B, args.nb_nodes)
            L_beamsearch = L_beamsearch.view(args.bsz, B)
            L_beamsearch_tmp = L_beamsearch
            L_beamsearch, idx_min = L_beamsearch.min(dim=1)
            mean_tour_length_beamsearch += L_beamsearch.mean().item()
            mean_scores_beamsearch += scores_beamsearch.mean().item()
            x_len_beamsearch = L_beamsearch
            gap_beamsearch += (x_len_beamsearch/ x_len_concorde - 1.0).sum()
    torch.cuda.empty_cache() # free GPU reserved memory
if greedy:
    mean_tour_length_greedy =  mean_tour_length_greedy/ args.nb_batch_eval
    mean_scores_greedy =  mean_scores_greedy/ args.nb_batch_eval
    gap_greedy = (gap_greedy/ nb_TSPs).item()
if beamsearch:
    mean_tour_length_beamsearch =  mean_tour_length_beamsearch/ args.nb_batch_eval
    mean_scores_beamsearch =  mean_scores_beamsearch/ args.nb_batch_eval
    gap_beamsearch /= nb_TSPs
tot_time = time.time()-start
# Out:
# 2000
# batch index: 0, tot_time: 0.000min
# batch index: 1, tot_time: 0.011min
# batch index: 2, tot_time: 0.020min
# batch index: 3, tot_time: 0.030min
# batch index: 4, tot_time: 0.039min
# batch index: 5, tot_time: 0.049min
# batch index: 6, tot_time: 0.059min
# batch index: 7, tot_time: 0.069min
# batch index: 8, tot_time: 0.078min
# batch index: 9, tot_time: 0.088min
# batch index: 10, tot_time: 0.098min
# batch index: 11, tot_time: 0.108min
# batch index: 12, tot_time: 0.117min
# batch index: 13, tot_time: 0.127min
# batch index: 14, tot_time: 0.137min
# batch index: 15, tot_time: 0.147min
# batch index: 16, tot_time: 0.157min
# batch index: 17, tot_time: 0.167min
# batch index: 18, tot_time: 0.177min
# batch index: 19, tot_time: 0.186min
# batch index: 20, tot_time: 0.196min
# batch index: 21, tot_time: 0.206min
# batch index: 22, tot_time: 0.216min
# batch index: 23, tot_time: 0.225min
# batch index: 24, tot_time: 0.235min
# batch index: 25, tot_time: 0.245min
# batch index: 26, tot_time: 0.255min
# batch index: 27, tot_time: 0.264min
# batch index: 28, tot_time: 0.274min
# batch index: 29, tot_time: 0.284min
# batch index: 30, tot_time: 0.294min
# batch index: 31, tot_time: 0.303min
# batch index: 32, tot_time: 0.313min
# batch index: 33, tot_time: 0.323min
# batch index: 34, tot_time: 0.333min
# batch index: 35, tot_time: 0.343min
# batch index: 36, tot_time: 0.353min
# batch index: 37, tot_time: 0.363min
# batch index: 38, tot_time: 0.373min
# batch index: 39, tot_time: 0.383min
# batch index: 40, tot_time: 0.393min
# batch index: 41, tot_time: 0.403min
# batch index: 42, tot_time: 0.413min
# batch index: 43, tot_time: 0.423min
# batch index: 44, tot_time: 0.433min
# batch index: 45, tot_time: 0.442min
# batch index: 46, tot_time: 0.452min
# batch index: 47, tot_time: 0.462min
# batch index: 48, tot_time: 0.472min
# batch index: 49, tot_time: 0.482min
# batch index: 50, tot_time: 0.491min
# batch index: 51, tot_time: 0.501min
# batch index: 52, tot_time: 0.511min
# batch index: 53, tot_time: 0.521min
# batch index: 54, tot_time: 0.531min
# batch index: 55, tot_time: 0.541min
# batch index: 56, tot_time: 0.551min
# batch index: 57, tot_time: 0.561min
# batch index: 58, tot_time: 0.571min
# batch index: 59, tot_time: 0.581min
# batch index: 60, tot_time: 0.591min
# batch index: 61, tot_time: 0.601min
# batch index: 62, tot_time: 0.611min
# batch index: 63, tot_time: 0.621min
# batch index: 64, tot_time: 0.631min
# batch index: 65, tot_time: 0.640min
# batch index: 66, tot_time: 0.650min
# batch index: 67, tot_time: 0.660min
# batch index: 68, tot_time: 0.670min
# batch index: 69, tot_time: 0.680min
# batch index: 70, tot_time: 0.690min
# batch index: 71, tot_time: 0.700min
# batch index: 72, tot_time: 0.709min
# batch index: 73, tot_time: 0.719min
# batch index: 74, tot_time: 0.729min
# batch index: 75, tot_time: 0.739min
# batch index: 76, tot_time: 0.749min
# batch index: 77, tot_time: 0.759min
# batch index: 78, tot_time: 0.769min
# batch index: 79, tot_time: 0.779min
# batch index: 80, tot_time: 0.789min
# batch index: 81, tot_time: 0.799min
# batch index: 82, tot_time: 0.809min
# batch index: 83, tot_time: 0.819min
# batch index: 84, tot_time: 0.828min
# batch index: 85, tot_time: 0.838min
# batch index: 86, tot_time: 0.848min
# batch index: 87, tot_time: 0.858min
# batch index: 88, tot_time: 0.867min
# batch index: 89, tot_time: 0.877min
# batch index: 90, tot_time: 0.887min
# batch index: 91, tot_time: 0.897min
# batch index: 92, tot_time: 0.907min
# batch index: 93, tot_time: 0.916min
# batch index: 94, tot_time: 0.926min
# batch index: 95, tot_time: 0.936min
# batch index: 96, tot_time: 0.946min
# batch index: 97, tot_time: 0.956min
# batch index: 98, tot_time: 0.966min
# batch index: 99, tot_time: 0.976min
# batch index: 100, tot_time: 0.986min
# batch index: 101, tot_time: 0.996min
# batch index: 102, tot_time: 1.006min
# batch index: 103, tot_time: 1.016min
# batch index: 104, tot_time: 1.025min
# batch index: 105, tot_time: 1.035min
# batch index: 106, tot_time: 1.045min
# batch index: 107, tot_time: 1.055min
# batch index: 108, tot_time: 1.064min
# batch index: 109, tot_time: 1.074min
# batch index: 110, tot_time: 1.084min
# batch index: 111, tot_time: 1.093min
# batch index: 112, tot_time: 1.103min
# batch index: 113, tot_time: 1.113min
# batch index: 114, tot_time: 1.123min
# batch index: 115, tot_time: 1.133min
# batch index: 116, tot_time: 1.142min
# batch index: 117, tot_time: 1.152min
# batch index: 118, tot_time: 1.162min
# batch index: 119, tot_time: 1.172min
# batch index: 120, tot_time: 1.182min
# batch index: 121, tot_time: 1.192min
# batch index: 122, tot_time: 1.202min
# batch index: 123, tot_time: 1.212min
# batch index: 124, tot_time: 1.221min
# batch index: 125, tot_time: 1.231min
# batch index: 126, tot_time: 1.241min
# batch index: 127, tot_time: 1.250min
# batch index: 128, tot_time: 1.260min
# batch index: 129, tot_time: 1.270min
# batch index: 130, tot_time: 1.280min
# batch index: 131, tot_time: 1.289min
# batch index: 132, tot_time: 1.299min
# batch index: 133, tot_time: 1.309min
# batch index: 134, tot_time: 1.319min
# batch index: 135, tot_time: 1.328min
# batch index: 136, tot_time: 1.338min
# batch index: 137, tot_time: 1.348min
# batch index: 138, tot_time: 1.358min
# batch index: 139, tot_time: 1.368min
# batch index: 140, tot_time: 1.378min
# batch index: 141, tot_time: 1.388min
# batch index: 142, tot_time: 1.398min
# batch index: 143, tot_time: 1.407min
# batch index: 144, tot_time: 1.417min
# batch index: 145, tot_time: 1.427min
# batch index: 146, tot_time: 1.437min
# batch index: 147, tot_time: 1.450min
# batch index: 148, tot_time: 1.462min
# batch index: 149, tot_time: 1.473min
# batch index: 150, tot_time: 1.484min
# batch index: 151, tot_time: 1.494min
# batch index: 152, tot_time: 1.503min
# batch index: 153, tot_time: 1.513min
# batch index: 154, tot_time: 1.523min
# batch index: 155, tot_time: 1.532min
# batch index: 156, tot_time: 1.542min
# batch index: 157, tot_time: 1.553min
# batch index: 158, tot_time: 1.563min
# batch index: 159, tot_time: 1.573min
# batch index: 160, tot_time: 1.583min
# batch index: 161, tot_time: 1.592min
# batch index: 162, tot_time: 1.602min
# batch index: 163, tot_time: 1.612min
# batch index: 164, tot_time: 1.622min
# batch index: 165, tot_time: 1.631min
# batch index: 166, tot_time: 1.641min
# batch index: 167, tot_time: 1.651min
# batch index: 168, tot_time: 1.660min
# batch index: 169, tot_time: 1.670min
# batch index: 170, tot_time: 1.680min
# batch index: 171, tot_time: 1.690min
# batch index: 172, tot_time: 1.699min
# batch index: 173, tot_time: 1.709min
# batch index: 174, tot_time: 1.719min
# batch index: 175, tot_time: 1.729min
# batch index: 176, tot_time: 1.739min
# batch index: 177, tot_time: 1.749min
# batch index: 178, tot_time: 1.758min
# batch index: 179, tot_time: 1.768min
# batch index: 180, tot_time: 1.779min
# batch index: 181, tot_time: 1.788min
# batch index: 182, tot_time: 1.798min
# batch index: 183, tot_time: 1.808min
# batch index: 184, tot_time: 1.818min
# batch index: 185, tot_time: 1.828min
# batch index: 186, tot_time: 1.837min
# batch index: 187, tot_time: 1.847min
# batch index: 188, tot_time: 1.857min
# batch index: 189, tot_time: 1.867min
# batch index: 190, tot_time: 1.877min
# batch index: 191, tot_time: 1.886min
# batch index: 192, tot_time: 1.896min
# batch index: 193, tot_time: 1.906min
# batch index: 194, tot_time: 1.916min
# batch index: 195, tot_time: 1.925min
# batch index: 196, tot_time: 1.935min
# batch index: 197, tot_time: 1.945min
# batch index: 198, tot_time: 1.955min
# batch index: 199, tot_time: 1.965min
# batch index: 200, tot_time: 1.975min
# batch index: 201, tot_time: 1.985min
# batch index: 202, tot_time: 1.995min
# batch index: 203, tot_time: 2.005min
# batch index: 204, tot_time: 2.014min
# batch index: 205, tot_time: 2.024min
# batch index: 206, tot_time: 2.034min
# batch index: 207, tot_time: 2.044min
# batch index: 208, tot_time: 2.054min
# batch index: 209, tot_time: 2.063min
# batch index: 210, tot_time: 2.073min
# batch index: 211, tot_time: 2.083min
# batch index: 212, tot_time: 2.093min
# batch index: 213, tot_time: 2.103min
# batch index: 214, tot_time: 2.112min
# batch index: 215, tot_time: 2.122min
# batch index: 216, tot_time: 2.132min
# batch index: 217, tot_time: 2.142min
# batch index: 218, tot_time: 2.152min
# batch index: 219, tot_time: 2.162min
# batch index: 220, tot_time: 2.172min
# batch index: 221, tot_time: 2.182min
# batch index: 222, tot_time: 2.192min
# batch index: 223, tot_time: 2.202min
# batch index: 224, tot_time: 2.211min
# batch index: 225, tot_time: 2.221min
# batch index: 226, tot_time: 2.231min
# batch index: 227, tot_time: 2.241min
# batch index: 228, tot_time: 2.250min
# batch index: 229, tot_time: 2.260min
# batch index: 230, tot_time: 2.270min
# batch index: 231, tot_time: 2.280min
# batch index: 232, tot_time: 2.290min
# batch index: 233, tot_time: 2.299min
# batch index: 234, tot_time: 2.309min
# batch index: 235, tot_time: 2.319min
# batch index: 236, tot_time: 2.329min
# batch index: 237, tot_time: 2.338min
# batch index: 238, tot_time: 2.348min
# batch index: 239, tot_time: 2.358min
# batch index: 240, tot_time: 2.369min
# batch index: 241, tot_time: 2.379min
# batch index: 242, tot_time: 2.388min
# batch index: 243, tot_time: 2.398min
# batch index: 244, tot_time: 2.408min
# batch index: 245, tot_time: 2.418min
# batch index: 246, tot_time: 2.428min
# batch index: 247, tot_time: 2.437min
# batch index: 248, tot_time: 2.447min
# batch index: 249, tot_time: 2.457min
# batch index: 250, tot_time: 2.467min
# batch index: 251, tot_time: 2.476min
# batch index: 252, tot_time: 2.486min
# batch index: 253, tot_time: 2.496min
# batch index: 254, tot_time: 2.506min
# batch index: 255, tot_time: 2.515min
# batch index: 256, tot_time: 2.525min
# batch index: 257, tot_time: 2.535min
# batch index: 258, tot_time: 2.545min
# batch index: 259, tot_time: 2.555min
# batch index: 260, tot_time: 2.565min
# batch index: 261, tot_time: 2.576min
# batch index: 262, tot_time: 2.586min
# batch index: 263, tot_time: 2.596min
# batch index: 264, tot_time: 2.605min
# batch index: 265, tot_time: 2.615min
# batch index: 266, tot_time: 2.625min
# batch index: 267, tot_time: 2.635min
# batch index: 268, tot_time: 2.644min
# batch index: 269, tot_time: 2.654min
# batch index: 270, tot_time: 2.664min
# batch index: 271, tot_time: 2.674min
# batch index: 272, tot_time: 2.683min
# batch index: 273, tot_time: 2.693min
# batch index: 274, tot_time: 2.703min
# batch index: 275, tot_time: 2.713min
# batch index: 276, tot_time: 2.722min
# batch index: 277, tot_time: 2.732min
# batch index: 278, tot_time: 2.742min
# batch index: 279, tot_time: 2.752min
# batch index: 280, tot_time: 2.762min
# batch index: 281, tot_time: 2.772min
# batch index: 282, tot_time: 2.782min
# batch index: 283, tot_time: 2.792min
# batch index: 284, tot_time: 2.801min
# batch index: 285, tot_time: 2.811min
# batch index: 286, tot_time: 2.821min
# batch index: 287, tot_time: 2.831min
# batch index: 288, tot_time: 2.840min
# batch index: 289, tot_time: 2.850min
# batch index: 290, tot_time: 2.860min
# batch index: 291, tot_time: 2.870min
# batch index: 292, tot_time: 2.879min
# batch index: 293, tot_time: 2.889min
# batch index: 294, tot_time: 2.899min
# batch index: 295, tot_time: 2.909min
# batch index: 296, tot_time: 2.918min
# batch index: 297, tot_time: 2.928min
# batch index: 298, tot_time: 2.938min
# batch index: 299, tot_time: 2.948min
# batch index: 300, tot_time: 2.958min
# batch index: 301, tot_time: 2.968min
# batch index: 302, tot_time: 2.978min
# batch index: 303, tot_time: 2.988min
# batch index: 304, tot_time: 2.998min
# batch index: 305, tot_time: 3.008min
# batch index: 306, tot_time: 3.017min
# batch index: 307, tot_time: 3.027min
# batch index: 308, tot_time: 3.037min
# batch index: 309, tot_time: 3.047min
# batch index: 310, tot_time: 3.056min
# batch index: 311, tot_time: 3.066min
# batch index: 312, tot_time: 3.076min
# batch index: 313, tot_time: 3.086min
# batch index: 314, tot_time: 3.095min
# batch index: 315, tot_time: 3.105min
# batch index: 316, tot_time: 3.115min
# batch index: 317, tot_time: 3.124min
# batch index: 318, tot_time: 3.134min
# batch index: 319, tot_time: 3.144min
# batch index: 320, tot_time: 3.154min
# batch index: 321, tot_time: 3.164min
# batch index: 322, tot_time: 3.174min
# batch index: 323, tot_time: 3.184min
# batch index: 324, tot_time: 3.194min
# batch index: 325, tot_time: 3.204min
# batch index: 326, tot_time: 3.213min
# batch index: 327, tot_time: 3.223min
# batch index: 328, tot_time: 3.233min
# batch index: 329, tot_time: 3.243min
# batch index: 330, tot_time: 3.252min
# batch index: 331, tot_time: 3.262min
# batch index: 332, tot_time: 3.272min
# batch index: 333, tot_time: 3.282min
# batch index: 334, tot_time: 3.291min
# batch index: 335, tot_time: 3.301min
# batch index: 336, tot_time: 3.311min
# batch index: 337, tot_time: 3.321min
# batch index: 338, tot_time: 3.330min
# batch index: 339, tot_time: 3.340min
# batch index: 340, tot_time: 3.350min
# batch index: 341, tot_time: 3.360min
# batch index: 342, tot_time: 3.370min
# batch index: 343, tot_time: 3.381min
# batch index: 344, tot_time: 3.390min
# batch index: 345, tot_time: 3.400min
# batch index: 346, tot_time: 3.410min
# batch index: 347, tot_time: 3.420min
# batch index: 348, tot_time: 3.429min
# batch index: 349, tot_time: 3.439min
# batch index: 350, tot_time: 3.449min
# batch index: 351, tot_time: 3.459min
# batch index: 352, tot_time: 3.469min
# batch index: 353, tot_time: 3.478min
# batch index: 354, tot_time: 3.488min
# batch index: 355, tot_time: 3.498min
# batch index: 356, tot_time: 3.508min
# batch index: 357, tot_time: 3.517min
# batch index: 358, tot_time: 3.527min
# batch index: 359, tot_time: 3.537min
# batch index: 360, tot_time: 3.547min
# batch index: 361, tot_time: 3.557min
# batch index: 362, tot_time: 3.567min
# batch index: 363, tot_time: 3.577min
# batch index: 364, tot_time: 3.587min
# batch index: 365, tot_time: 3.597min
# batch index: 366, tot_time: 3.606min
# batch index: 367, tot_time: 3.616min
# batch index: 368, tot_time: 3.626min
# batch index: 369, tot_time: 3.636min
# batch index: 370, tot_time: 3.645min
# batch index: 371, tot_time: 3.655min
# batch index: 372, tot_time: 3.665min
# batch index: 373, tot_time: 3.675min
# batch index: 374, tot_time: 3.685min
# batch index: 375, tot_time: 3.694min
# batch index: 376, tot_time: 3.704min
# batch index: 377, tot_time: 3.714min
# batch index: 378, tot_time: 3.724min
# batch index: 379, tot_time: 3.733min
# batch index: 380, tot_time: 3.743min
# batch index: 381, tot_time: 3.753min
# batch index: 382, tot_time: 3.763min
# batch index: 383, tot_time: 3.773min
# batch index: 384, tot_time: 3.783min
# batch index: 385, tot_time: 3.793min
# batch index: 386, tot_time: 3.803min
# batch index: 387, tot_time: 3.813min
# batch index: 388, tot_time: 3.822min
# batch index: 389, tot_time: 3.832min
# batch index: 390, tot_time: 3.842min
# batch index: 391, tot_time: 3.852min
# batch index: 392, tot_time: 3.861min
# batch index: 393, tot_time: 3.871min
# batch index: 394, tot_time: 3.881min
# batch index: 395, tot_time: 3.891min
# batch index: 396, tot_time: 3.901min
# batch index: 397, tot_time: 3.910min
# batch index: 398, tot_time: 3.920min
# batch index: 399, tot_time: 3.930min
# batch index: 400, tot_time: 3.940min
# batch index: 401, tot_time: 3.950min
# batch index: 402, tot_time: 3.960min
# batch index: 403, tot_time: 3.970min
# batch index: 404, tot_time: 3.980min
# batch index: 405, tot_time: 3.990min
# batch index: 406, tot_time: 3.999min
# batch index: 407, tot_time: 4.009min
# batch index: 408, tot_time: 4.019min
# batch index: 409, tot_time: 4.029min
# batch index: 410, tot_time: 4.038min
# batch index: 411, tot_time: 4.048min
# batch index: 412, tot_time: 4.058min
# batch index: 413, tot_time: 4.068min
# batch index: 414, tot_time: 4.078min
# batch index: 415, tot_time: 4.087min
# batch index: 416, tot_time: 4.097min
# batch index: 417, tot_time: 4.107min
# batch index: 418, tot_time: 4.117min
# batch index: 419, tot_time: 4.126min
# batch index: 420, tot_time: 4.136min
# batch index: 421, tot_time: 4.146min
# batch index: 422, tot_time: 4.156min
# batch index: 423, tot_time: 4.166min
# batch index: 424, tot_time: 4.176min
# batch index: 425, tot_time: 4.186min
# batch index: 426, tot_time: 4.196min
# batch index: 427, tot_time: 4.206min
# batch index: 428, tot_time: 4.215min
# batch index: 429, tot_time: 4.225min
# batch index: 430, tot_time: 4.235min
# batch index: 431, tot_time: 4.245min
# batch index: 432, tot_time: 4.254min
# batch index: 433, tot_time: 4.264min
# batch index: 434, tot_time: 4.274min
# batch index: 435, tot_time: 4.284min
# batch index: 436, tot_time: 4.293min
# batch index: 437, tot_time: 4.303min
# batch index: 438, tot_time: 4.313min
# batch index: 439, tot_time: 4.323min
# batch index: 440, tot_time: 4.332min
# batch index: 441, tot_time: 4.342min
# batch index: 442, tot_time: 4.352min
# batch index: 443, tot_time: 4.362min
# batch index: 444, tot_time: 4.372min
# batch index: 445, tot_time: 4.382min
# batch index: 446, tot_time: 4.392min
# batch index: 447, tot_time: 4.402min
# batch index: 448, tot_time: 4.412min
# batch index: 449, tot_time: 4.422min
# batch index: 450, tot_time: 4.432min
# batch index: 451, tot_time: 4.441min
# batch index: 452, tot_time: 4.451min
# batch index: 453, tot_time: 4.461min
# batch index: 454, tot_time: 4.471min
# batch index: 455, tot_time: 4.480min
# batch index: 456, tot_time: 4.490min
# batch index: 457, tot_time: 4.500min
# batch index: 458, tot_time: 4.510min
# batch index: 459, tot_time: 4.519min
# batch index: 460, tot_time: 4.529min
# batch index: 461, tot_time: 4.539min
# batch index: 462, tot_time: 4.549min
# batch index: 463, tot_time: 4.559min
# batch index: 464, tot_time: 4.569min
# batch index: 465, tot_time: 4.579min
# batch index: 466, tot_time: 4.589min
# batch index: 467, tot_time: 4.599min
# batch index: 468, tot_time: 4.608min
# batch index: 469, tot_time: 4.618min
# batch index: 470, tot_time: 4.628min
# batch index: 471, tot_time: 4.638min
# batch index: 472, tot_time: 4.648min
# batch index: 473, tot_time: 4.657min
# batch index: 474, tot_time: 4.667min
# batch index: 475, tot_time: 4.677min
# batch index: 476, tot_time: 4.686min
# batch index: 477, tot_time: 4.696min
# batch index: 478, tot_time: 4.706min
# batch index: 479, tot_time: 4.716min
# batch index: 480, tot_time: 4.726min
# batch index: 481, tot_time: 4.735min
# batch index: 482, tot_time: 4.745min
# batch index: 483, tot_time: 4.755min
# batch index: 484, tot_time: 4.765min
# batch index: 485, tot_time: 4.776min
# batch index: 486, tot_time: 4.785min
# batch index: 487, tot_time: 4.795min
# batch index: 488, tot_time: 4.805min
# batch index: 489, tot_time: 4.815min
# batch index: 490, tot_time: 4.824min
# batch index: 491, tot_time: 4.834min
# batch index: 492, tot_time: 4.844min
# batch index: 493, tot_time: 4.854min
# batch index: 494, tot_time: 4.863min
# batch index: 495, tot_time: 4.873min
# batch index: 496, tot_time: 4.883min
# batch index: 497, tot_time: 4.893min
# batch index: 498, tot_time: 4.902min
# batch index: 499, tot_time: 4.912min
# batch index: 500, tot_time: 4.922min
# batch index: 501, tot_time: 4.932min
# batch index: 502, tot_time: 4.942min
# batch index: 503, tot_time: 4.952min
# batch index: 504, tot_time: 4.962min
# batch index: 505, tot_time: 4.972min
# batch index: 506, tot_time: 4.982min
# batch index: 507, tot_time: 4.992min
# batch index: 508, tot_time: 5.001min
# batch index: 509, tot_time: 5.011min
# batch index: 510, tot_time: 5.021min
# batch index: 511, tot_time: 5.031min
# batch index: 512, tot_time: 5.040min
# batch index: 513, tot_time: 5.050min
# batch index: 514, tot_time: 5.060min
# batch index: 515, tot_time: 5.070min
# batch index: 516, tot_time: 5.080min
# batch index: 517, tot_time: 5.089min
# batch index: 518, tot_time: 5.099min
# batch index: 519, tot_time: 5.109min
# batch index: 520, tot_time: 5.119min
# batch index: 521, tot_time: 5.128min
# batch index: 522, tot_time: 5.138min
# batch index: 523, tot_time: 5.148min
# batch index: 524, tot_time: 5.158min
# batch index: 525, tot_time: 5.168min
# batch index: 526, tot_time: 5.178min
# batch index: 527, tot_time: 5.188min
# batch index: 528, tot_time: 5.198min
# batch index: 529, tot_time: 5.208min
# batch index: 530, tot_time: 5.217min
# batch index: 531, tot_time: 5.227min
# batch index: 532, tot_time: 5.237min
# batch index: 533, tot_time: 5.246min
# batch index: 534, tot_time: 5.256min
# batch index: 535, tot_time: 5.266min
# batch index: 536, tot_time: 5.276min
# batch index: 537, tot_time: 5.285min
# batch index: 538, tot_time: 5.295min
# batch index: 539, tot_time: 5.305min
# batch index: 540, tot_time: 5.315min
# batch index: 541, tot_time: 5.324min
# batch index: 542, tot_time: 5.334min
# batch index: 543, tot_time: 5.344min
# batch index: 544, tot_time: 5.354min
# batch index: 545, tot_time: 5.364min
# batch index: 546, tot_time: 5.374min
# batch index: 547, tot_time: 5.384min
# batch index: 548, tot_time: 5.394min
# batch index: 549, tot_time: 5.404min
# batch index: 550, tot_time: 5.413min
# batch index: 551, tot_time: 5.423min
# batch index: 552, tot_time: 5.433min
# batch index: 553, tot_time: 5.443min
# batch index: 554, tot_time: 5.452min
# batch index: 555, tot_time: 5.462min
# batch index: 556, tot_time: 5.472min
# batch index: 557, tot_time: 5.482min
# batch index: 558, tot_time: 5.491min
# batch index: 559, tot_time: 5.501min
# batch index: 560, tot_time: 5.511min
# batch index: 561, tot_time: 5.521min
# batch index: 562, tot_time: 5.530min
# batch index: 563, tot_time: 5.540min
# batch index: 564, tot_time: 5.550min
# batch index: 565, tot_time: 5.560min
# batch index: 566, tot_time: 5.570min
# batch index: 567, tot_time: 5.580min
# batch index: 568, tot_time: 5.590min
# batch index: 569, tot_time: 5.600min
# batch index: 570, tot_time: 5.610min
# batch index: 571, tot_time: 5.619min
# batch index: 572, tot_time: 5.629min
# batch index: 573, tot_time: 5.639min
# batch index: 574, tot_time: 5.649min
# batch index: 575, tot_time: 5.658min
# batch index: 576, tot_time: 5.668min
# batch index: 577, tot_time: 5.678min
# batch index: 578, tot_time: 5.688min
# batch index: 579, tot_time: 5.697min
# batch index: 580, tot_time: 5.707min
# batch index: 581, tot_time: 5.717min
# batch index: 582, tot_time: 5.726min
# batch index: 583, tot_time: 5.736min
# batch index: 584, tot_time: 5.746min
# batch index: 585, tot_time: 5.756min
# batch index: 586, tot_time: 5.766min
# batch index: 587, tot_time: 5.776min
# batch index: 588, tot_time: 5.786min
# batch index: 589, tot_time: 5.796min
# batch index: 590, tot_time: 5.805min
# batch index: 591, tot_time: 5.815min
# batch index: 592, tot_time: 5.825min
# batch index: 593, tot_time: 5.835min
# batch index: 594, tot_time: 5.844min
# batch index: 595, tot_time: 5.854min
# batch index: 596, tot_time: 5.864min
# batch index: 597, tot_time: 5.874min
# batch index: 598, tot_time: 5.883min
# batch index: 599, tot_time: 5.893min
# batch index: 600, tot_time: 5.903min
# batch index: 601, tot_time: 5.913min
# batch index: 602, tot_time: 5.922min
# batch index: 603, tot_time: 5.932min
# batch index: 604, tot_time: 5.942min
# batch index: 605, tot_time: 5.952min
# batch index: 606, tot_time: 5.962min
# batch index: 607, tot_time: 5.972min
# batch index: 608, tot_time: 5.982min
# batch index: 609, tot_time: 5.992min
# batch index: 610, tot_time: 6.001min
# batch index: 611, tot_time: 6.011min
# batch index: 612, tot_time: 6.021min
# batch index: 613, tot_time: 6.031min
# batch index: 614, tot_time: 6.040min
# batch index: 615, tot_time: 6.050min
# batch index: 616, tot_time: 6.060min
# batch index: 617, tot_time: 6.070min
# batch index: 618, tot_time: 6.079min
# batch index: 619, tot_time: 6.089min
# batch index: 620, tot_time: 6.099min
# batch index: 621, tot_time: 6.109min
# batch index: 622, tot_time: 6.118min
# batch index: 623, tot_time: 6.128min
# batch index: 624, tot_time: 6.138min
# batch index: 625, tot_time: 6.148min
# batch index: 626, tot_time: 6.158min
# batch index: 627, tot_time: 6.168min
# batch index: 628, tot_time: 6.178min
# batch index: 629, tot_time: 6.188min
# batch index: 630, tot_time: 6.198min
# batch index: 631, tot_time: 6.207min
# batch index: 632, tot_time: 6.217min
# batch index: 633, tot_time: 6.227min
# batch index: 634, tot_time: 6.236min
# batch index: 635, tot_time: 6.246min
# batch index: 636, tot_time: 6.256min
# batch index: 637, tot_time: 6.266min
# batch index: 638, tot_time: 6.275min
# batch index: 639, tot_time: 6.285min
# batch index: 640, tot_time: 6.295min
# batch index: 641, tot_time: 6.305min
# batch index: 642, tot_time: 6.314min
# batch index: 643, tot_time: 6.324min
# batch index: 644, tot_time: 6.334min
# batch index: 645, tot_time: 6.344min
# batch index: 646, tot_time: 6.354min
# batch index: 647, tot_time: 6.364min
# batch index: 648, tot_time: 6.374min
# batch index: 649, tot_time: 6.384min
# batch index: 650, tot_time: 6.393min
# batch index: 651, tot_time: 6.403min
# batch index: 652, tot_time: 6.413min
# batch index: 653, tot_time: 6.423min
# batch index: 654, tot_time: 6.433min
# batch index: 655, tot_time: 6.442min
# batch index: 656, tot_time: 6.452min
# batch index: 657, tot_time: 6.462min
# batch index: 658, tot_time: 6.471min
# batch index: 659, tot_time: 6.481min
# batch index: 660, tot_time: 6.491min
# batch index: 661, tot_time: 6.501min
# batch index: 662, tot_time: 6.510min
# batch index: 663, tot_time: 6.520min
# batch index: 664, tot_time: 6.530min
# batch index: 665, tot_time: 6.540min
# batch index: 666, tot_time: 6.550min
# batch index: 667, tot_time: 6.560min
# batch index: 668, tot_time: 6.570min
# batch index: 669, tot_time: 6.580min
# batch index: 670, tot_time: 6.590min
# batch index: 671, tot_time: 6.599min
# batch index: 672, tot_time: 6.609min
# batch index: 673, tot_time: 6.619min
# batch index: 674, tot_time: 6.629min
# batch index: 675, tot_time: 6.638min
# batch index: 676, tot_time: 6.648min
# batch index: 677, tot_time: 6.658min
# batch index: 678, tot_time: 6.668min
# batch index: 679, tot_time: 6.677min
# batch index: 680, tot_time: 6.687min
# batch index: 681, tot_time: 6.697min
# batch index: 682, tot_time: 6.707min
# batch index: 683, tot_time: 6.716min
# batch index: 684, tot_time: 6.726min
# batch index: 685, tot_time: 6.736min
# batch index: 686, tot_time: 6.746min
# batch index: 687, tot_time: 6.756min
# batch index: 688, tot_time: 6.766min
# batch index: 689, tot_time: 6.776min
# batch index: 690, tot_time: 6.786min
# batch index: 691, tot_time: 6.796min
# batch index: 692, tot_time: 6.805min
# batch index: 693, tot_time: 6.815min
# batch index: 694, tot_time: 6.825min
# batch index: 695, tot_time: 6.835min
# batch index: 696, tot_time: 6.844min
# batch index: 697, tot_time: 6.854min
# batch index: 698, tot_time: 6.864min
# batch index: 699, tot_time: 6.874min
# batch index: 700, tot_time: 6.883min
# batch index: 701, tot_time: 6.893min
# batch index: 702, tot_time: 6.903min
# batch index: 703, tot_time: 6.913min
# batch index: 704, tot_time: 6.923min
# batch index: 705, tot_time: 6.932min
# batch index: 706, tot_time: 6.942min
# batch index: 707, tot_time: 6.952min
# batch index: 708, tot_time: 6.963min
# batch index: 709, tot_time: 6.973min
# batch index: 710, tot_time: 6.982min
# batch index: 711, tot_time: 6.992min
# batch index: 712, tot_time: 7.002min
# batch index: 713, tot_time: 7.012min
# batch index: 714, tot_time: 7.021min
# batch index: 715, tot_time: 7.031min
# batch index: 716, tot_time: 7.041min
# batch index: 717, tot_time: 7.051min
# batch index: 718, tot_time: 7.060min
# batch index: 719, tot_time: 7.070min
# batch index: 720, tot_time: 7.080min
# batch index: 721, tot_time: 7.090min
# batch index: 722, tot_time: 7.099min
# batch index: 723, tot_time: 7.109min
# batch index: 724, tot_time: 7.119min
# batch index: 725, tot_time: 7.129min
# batch index: 726, tot_time: 7.138min
# batch index: 727, tot_time: 7.149min
# batch index: 728, tot_time: 7.159min
# batch index: 729, tot_time: 7.169min
# batch index: 730, tot_time: 7.179min
# batch index: 731, tot_time: 7.188min
# batch index: 732, tot_time: 7.198min
# batch index: 733, tot_time: 7.208min
# batch index: 734, tot_time: 7.218min
# batch index: 735, tot_time: 7.227min
# batch index: 736, tot_time: 7.237min
# batch index: 737, tot_time: 7.247min
# batch index: 738, tot_time: 7.257min
# batch index: 739, tot_time: 7.266min
# batch index: 740, tot_time: 7.276min
# batch index: 741, tot_time: 7.286min
# batch index: 742, tot_time: 7.296min
# batch index: 743, tot_time: 7.305min
# batch index: 744, tot_time: 7.315min
# batch index: 745, tot_time: 7.325min
# batch index: 746, tot_time: 7.335min
# batch index: 747, tot_time: 7.345min
# batch index: 748, tot_time: 7.355min
# batch index: 749, tot_time: 7.365min
# batch index: 750, tot_time: 7.375min
# batch index: 751, tot_time: 7.385min
# batch index: 752, tot_time: 7.394min
# batch index: 753, tot_time: 7.404min
# batch index: 754, tot_time: 7.414min
# batch index: 755, tot_time: 7.424min
# batch index: 756, tot_time: 7.433min
# batch index: 757, tot_time: 7.443min
# batch index: 758, tot_time: 7.453min
# batch index: 759, tot_time: 7.463min
# batch index: 760, tot_time: 7.473min
# batch index: 761, tot_time: 7.482min
# batch index: 762, tot_time: 7.492min
# batch index: 763, tot_time: 7.502min
# batch index: 764, tot_time: 7.512min
# batch index: 765, tot_time: 7.521min
# batch index: 766, tot_time: 7.531min
# batch index: 767, tot_time: 7.541min
# batch index: 768, tot_time: 7.551min
# batch index: 769, tot_time: 7.561min
# batch index: 770, tot_time: 7.571min
# batch index: 771, tot_time: 7.581min
# batch index: 772, tot_time: 7.591min
# batch index: 773, tot_time: 7.600min
# batch index: 774, tot_time: 7.610min
# batch index: 775, tot_time: 7.620min
# batch index: 776, tot_time: 7.629min
# batch index: 777, tot_time: 7.639min
# batch index: 778, tot_time: 7.649min
# batch index: 779, tot_time: 7.659min
# batch index: 780, tot_time: 7.668min
# batch index: 781, tot_time: 7.678min
# batch index: 782, tot_time: 7.688min
# batch index: 783, tot_time: 7.698min
# batch index: 784, tot_time: 7.707min
# batch index: 785, tot_time: 7.717min
# batch index: 786, tot_time: 7.727min
# batch index: 787, tot_time: 7.737min
# batch index: 788, tot_time: 7.747min
# batch index: 789, tot_time: 7.757min
# batch index: 790, tot_time: 7.767min
# batch index: 791, tot_time: 7.777min
# batch index: 792, tot_time: 7.787min
# batch index: 793, tot_time: 7.796min
# batch index: 794, tot_time: 7.806min
# batch index: 795, tot_time: 7.816min
# batch index: 796, tot_time: 7.826min
# batch index: 797, tot_time: 7.835min
# batch index: 798, tot_time: 7.845min
# batch index: 799, tot_time: 7.855min
# batch index: 800, tot_time: 7.865min
# batch index: 801, tot_time: 7.874min
# batch index: 802, tot_time: 7.884min
# batch index: 803, tot_time: 7.894min
# batch index: 804, tot_time: 7.903min
# batch index: 805, tot_time: 7.913min
# batch index: 806, tot_time: 7.923min
# batch index: 807, tot_time: 7.933min
# batch index: 808, tot_time: 7.943min
# batch index: 809, tot_time: 7.953min
# batch index: 810, tot_time: 7.963min
# batch index: 811, tot_time: 7.973min
# batch index: 812, tot_time: 7.983min
# batch index: 813, tot_time: 7.993min
# batch index: 814, tot_time: 8.003min
# batch index: 815, tot_time: 8.012min
# batch index: 816, tot_time: 8.022min
# batch index: 817, tot_time: 8.032min
# batch index: 818, tot_time: 8.042min
# batch index: 819, tot_time: 8.051min
# batch index: 820, tot_time: 8.061min
# batch index: 821, tot_time: 8.071min
# batch index: 822, tot_time: 8.081min
# batch index: 823, tot_time: 8.090min
# batch index: 824, tot_time: 8.100min
# batch index: 825, tot_time: 8.110min
# batch index: 826, tot_time: 8.120min
# batch index: 827, tot_time: 8.129min
# batch index: 828, tot_time: 8.139min
# batch index: 829, tot_time: 8.149min
# batch index: 830, tot_time: 8.159min
# batch index: 831, tot_time: 8.169min
# batch index: 832, tot_time: 8.179min
# batch index: 833, tot_time: 8.189min
# batch index: 834, tot_time: 8.199min
# batch index: 835, tot_time: 8.208min
# batch index: 836, tot_time: 8.218min
# batch index: 837, tot_time: 8.228min
# batch index: 838, tot_time: 8.238min
# batch index: 839, tot_time: 8.247min
# batch index: 840, tot_time: 8.257min
# batch index: 841, tot_time: 8.267min
# batch index: 842, tot_time: 8.277min
# batch index: 843, tot_time: 8.286min
# batch index: 844, tot_time: 8.296min
# batch index: 845, tot_time: 8.306min
# batch index: 846, tot_time: 8.316min
# batch index: 847, tot_time: 8.325min
# batch index: 848, tot_time: 8.335min
# batch index: 849, tot_time: 8.345min
# batch index: 850, tot_time: 8.355min
# batch index: 851, tot_time: 8.365min
# batch index: 852, tot_time: 8.375min
# batch index: 853, tot_time: 8.385min
# batch index: 854, tot_time: 8.395min
# batch index: 855, tot_time: 8.404min
# batch index: 856, tot_time: 8.414min
# batch index: 857, tot_time: 8.424min
# batch index: 858, tot_time: 8.434min
# batch index: 859, tot_time: 8.443min
# batch index: 860, tot_time: 8.453min
# batch index: 861, tot_time: 8.463min
# batch index: 862, tot_time: 8.473min
# batch index: 863, tot_time: 8.482min
# batch index: 864, tot_time: 8.492min
# batch index: 865, tot_time: 8.502min
# batch index: 866, tot_time: 8.512min
# batch index: 867, tot_time: 8.521min
# batch index: 868, tot_time: 8.531min
# batch index: 869, tot_time: 8.541min
# batch index: 870, tot_time: 8.551min
# batch index: 871, tot_time: 8.561min
# batch index: 872, tot_time: 8.571min
# batch index: 873, tot_time: 8.581min
# batch index: 874, tot_time: 8.591min
# batch index: 875, tot_time: 8.601min
# batch index: 876, tot_time: 8.610min
# batch index: 877, tot_time: 8.620min
# batch index: 878, tot_time: 8.630min
# batch index: 879, tot_time: 8.639min
# batch index: 880, tot_time: 8.649min
# batch index: 881, tot_time: 8.659min
# batch index: 882, tot_time: 8.669min
# batch index: 883, tot_time: 8.678min
# batch index: 884, tot_time: 8.688min
# batch index: 885, tot_time: 8.698min
# batch index: 886, tot_time: 8.708min
# batch index: 887, tot_time: 8.717min
# batch index: 888, tot_time: 8.727min
# batch index: 889, tot_time: 8.737min
# batch index: 890, tot_time: 8.747min
# batch index: 891, tot_time: 8.757min
# batch index: 892, tot_time: 8.767min
# batch index: 893, tot_time: 8.777min
# batch index: 894, tot_time: 8.787min
# batch index: 895, tot_time: 8.796min
# batch index: 896, tot_time: 8.806min
# batch index: 897, tot_time: 8.816min
# batch index: 898, tot_time: 8.826min
# batch index: 899, tot_time: 8.835min
# batch index: 900, tot_time: 8.845min
# batch index: 901, tot_time: 8.855min
# batch index: 902, tot_time: 8.865min
# batch index: 903, tot_time: 8.874min
# batch index: 904, tot_time: 8.884min
# batch index: 905, tot_time: 8.894min
# batch index: 906, tot_time: 8.904min
# batch index: 907, tot_time: 8.913min
# batch index: 908, tot_time: 8.923min
# batch index: 909, tot_time: 8.933min
# batch index: 910, tot_time: 8.943min
# batch index: 911, tot_time: 8.953min
# batch index: 912, tot_time: 8.963min
# batch index: 913, tot_time: 8.973min
# batch index: 914, tot_time: 8.983min
# batch index: 915, tot_time: 8.992min
# batch index: 916, tot_time: 9.002min
# batch index: 917, tot_time: 9.012min
# batch index: 918, tot_time: 9.022min
# batch index: 919, tot_time: 9.031min
# batch index: 920, tot_time: 9.041min
# batch index: 921, tot_time: 9.051min
# batch index: 922, tot_time: 9.061min
# batch index: 923, tot_time: 9.070min
# batch index: 924, tot_time: 9.080min
# batch index: 925, tot_time: 9.090min
# batch index: 926, tot_time: 9.100min
# batch index: 927, tot_time: 9.109min
# batch index: 928, tot_time: 9.119min
# batch index: 929, tot_time: 9.129min
# batch index: 930, tot_time: 9.139min
# batch index: 931, tot_time: 9.149min
# batch index: 932, tot_time: 9.159min
# batch index: 933, tot_time: 9.169min
# batch index: 934, tot_time: 9.179min
# batch index: 935, tot_time: 9.189min
# batch index: 936, tot_time: 9.199min
# batch index: 937, tot_time: 9.208min
# batch index: 938, tot_time: 9.218min
# batch index: 939, tot_time: 9.228min
# batch index: 940, tot_time: 9.238min
# batch index: 941, tot_time: 9.247min
# batch index: 942, tot_time: 9.257min
# batch index: 943, tot_time: 9.267min
# batch index: 944, tot_time: 9.276min
# batch index: 945, tot_time: 9.286min
# batch index: 946, tot_time: 9.296min
# batch index: 947, tot_time: 9.306min
# batch index: 948, tot_time: 9.315min
# batch index: 949, tot_time: 9.325min
# batch index: 950, tot_time: 9.335min
# batch index: 951, tot_time: 9.345min
# batch index: 952, tot_time: 9.355min
# batch index: 953, tot_time: 9.365min
# batch index: 954, tot_time: 9.375min
# batch index: 955, tot_time: 9.385min
# batch index: 956, tot_time: 9.395min
# batch index: 957, tot_time: 9.404min
# batch index: 958, tot_time: 9.414min
# batch index: 959, tot_time: 9.424min
# batch index: 960, tot_time: 9.434min
# batch index: 961, tot_time: 9.443min
# batch index: 962, tot_time: 9.453min
# batch index: 963, tot_time: 9.463min
# batch index: 964, tot_time: 9.472min
# batch index: 965, tot_time: 9.482min
# batch index: 966, tot_time: 9.492min
# batch index: 967, tot_time: 9.502min
# batch index: 968, tot_time: 9.512min
# batch index: 969, tot_time: 9.521min
# batch index: 970, tot_time: 9.531min
# batch index: 971, tot_time: 9.541min
# batch index: 972, tot_time: 9.551min
# batch index: 973, tot_time: 9.562min
# batch index: 974, tot_time: 9.571min
# batch index: 975, tot_time: 9.581min
# batch index: 976, tot_time: 9.591min
# batch index: 977, tot_time: 9.601min
# batch index: 978, tot_time: 9.610min
# batch index: 979, tot_time: 9.620min
# batch index: 980, tot_time: 9.630min
# batch index: 981, tot_time: 9.640min
# batch index: 982, tot_time: 9.650min
# batch index: 983, tot_time: 9.659min
# batch index: 984, tot_time: 9.669min
# batch index: 985, tot_time: 9.679min
# batch index: 986, tot_time: 9.689min
# batch index: 987, tot_time: 9.698min
# batch index: 988, tot_time: 9.708min
# batch index: 989, tot_time: 9.718min
# batch index: 990, tot_time: 9.728min
# batch index: 991, tot_time: 9.738min
# batch index: 992, tot_time: 9.748min
# batch index: 993, tot_time: 9.758min
# batch index: 994, tot_time: 9.768min
# batch index: 995, tot_time: 9.778min
# batch index: 996, tot_time: 9.788min
# batch index: 997, tot_time: 9.797min
# batch index: 998, tot_time: 9.807min
# batch index: 999, tot_time: 9.817min
# batch index: 1000, tot_time: 9.827min
# batch index: 1001, tot_time: 9.836min
# batch index: 1002, tot_time: 9.846min
# batch index: 1003, tot_time: 9.856min
# batch index: 1004, tot_time: 9.866min
# batch index: 1005, tot_time: 9.875min
# batch index: 1006, tot_time: 9.885min
# batch index: 1007, tot_time: 9.895min
# batch index: 1008, tot_time: 9.905min
# batch index: 1009, tot_time: 9.914min
# batch index: 1010, tot_time: 9.924min
# batch index: 1011, tot_time: 9.934min
# batch index: 1012, tot_time: 9.944min
# batch index: 1013, tot_time: 9.954min
# batch index: 1014, tot_time: 9.964min
# batch index: 1015, tot_time: 9.974min
# batch index: 1016, tot_time: 9.984min
# batch index: 1017, tot_time: 9.994min
# batch index: 1018, tot_time: 10.003min
# batch index: 1019, tot_time: 10.013min
# batch index: 1020, tot_time: 10.023min
# batch index: 1021, tot_time: 10.033min
# batch index: 1022, tot_time: 10.042min
# batch index: 1023, tot_time: 10.052min
# batch index: 1024, tot_time: 10.062min
# batch index: 1025, tot_time: 10.072min
# batch index: 1026, tot_time: 10.081min
# batch index: 1027, tot_time: 10.091min
# batch index: 1028, tot_time: 10.101min
# batch index: 1029, tot_time: 10.111min
# batch index: 1030, tot_time: 10.121min
# batch index: 1031, tot_time: 10.130min
# batch index: 1032, tot_time: 10.140min
# batch index: 1033, tot_time: 10.151min
# batch index: 1034, tot_time: 10.161min
# batch index: 1035, tot_time: 10.170min
# batch index: 1036, tot_time: 10.180min
# batch index: 1037, tot_time: 10.190min
# batch index: 1038, tot_time: 10.200min
# batch index: 1039, tot_time: 10.209min
# batch index: 1040, tot_time: 10.219min
# batch index: 1041, tot_time: 10.229min
# batch index: 1042, tot_time: 10.239min
# batch index: 1043, tot_time: 10.248min
# batch index: 1044, tot_time: 10.258min
# batch index: 1045, tot_time: 10.268min
# batch index: 1046, tot_time: 10.278min
# batch index: 1047, tot_time: 10.288min
# batch index: 1048, tot_time: 10.297min
# batch index: 1049, tot_time: 10.307min
# batch index: 1050, tot_time: 10.317min
# batch index: 1051, tot_time: 10.327min
# batch index: 1052, tot_time: 10.337min
# batch index: 1053, tot_time: 10.347min
# batch index: 1054, tot_time: 10.357min
# batch index: 1055, tot_time: 10.367min
# batch index: 1056, tot_time: 10.377min
# batch index: 1057, tot_time: 10.387min
# batch index: 1058, tot_time: 10.396min
# batch index: 1059, tot_time: 10.406min
# batch index: 1060, tot_time: 10.416min
# batch index: 1061, tot_time: 10.426min
# batch index: 1062, tot_time: 10.435min
# batch index: 1063, tot_time: 10.445min
# batch index: 1064, tot_time: 10.455min
# batch index: 1065, tot_time: 10.465min
# batch index: 1066, tot_time: 10.474min
# batch index: 1067, tot_time: 10.484min
# batch index: 1068, tot_time: 10.494min
# batch index: 1069, tot_time: 10.504min
# batch index: 1070, tot_time: 10.513min
# batch index: 1071, tot_time: 10.523min
# batch index: 1072, tot_time: 10.533min
# batch index: 1073, tot_time: 10.543min
# batch index: 1074, tot_time: 10.553min
# batch index: 1075, tot_time: 10.563min
# batch index: 1076, tot_time: 10.573min
# batch index: 1077, tot_time: 10.583min
# batch index: 1078, tot_time: 10.593min
# batch index: 1079, tot_time: 10.602min
# batch index: 1080, tot_time: 10.612min
# batch index: 1081, tot_time: 10.622min
# batch index: 1082, tot_time: 10.632min
# batch index: 1083, tot_time: 10.641min
# batch index: 1084, tot_time: 10.651min
# batch index: 1085, tot_time: 10.661min
# batch index: 1086, tot_time: 10.671min
# batch index: 1087, tot_time: 10.680min
# batch index: 1088, tot_time: 10.690min
# batch index: 1089, tot_time: 10.700min
# batch index: 1090, tot_time: 10.710min
# batch index: 1091, tot_time: 10.719min
# batch index: 1092, tot_time: 10.729min
# batch index: 1093, tot_time: 10.739min
# batch index: 1094, tot_time: 10.749min
# batch index: 1095, tot_time: 10.759min
# batch index: 1096, tot_time: 10.769min
# batch index: 1097, tot_time: 10.779min
# batch index: 1098, tot_time: 10.789min
# batch index: 1099, tot_time: 10.798min
# batch index: 1100, tot_time: 10.808min
# batch index: 1101, tot_time: 10.818min
# batch index: 1102, tot_time: 10.828min
# batch index: 1103, tot_time: 10.837min
# batch index: 1104, tot_time: 10.847min
# batch index: 1105, tot_time: 10.857min
# batch index: 1106, tot_time: 10.867min
# batch index: 1107, tot_time: 10.876min
# batch index: 1108, tot_time: 10.886min
# batch index: 1109, tot_time: 10.896min
# batch index: 1110, tot_time: 10.906min
# batch index: 1111, tot_time: 10.916min
# batch index: 1112, tot_time: 10.925min
# batch index: 1113, tot_time: 10.936min
# batch index: 1114, tot_time: 10.946min
# batch index: 1115, tot_time: 10.956min
# batch index: 1116, tot_time: 10.966min
# batch index: 1117, tot_time: 10.975min
# batch index: 1118, tot_time: 10.985min
# batch index: 1119, tot_time: 10.995min
# batch index: 1120, tot_time: 11.005min
# batch index: 1121, tot_time: 11.014min
# batch index: 1122, tot_time: 11.024min
# batch index: 1123, tot_time: 11.034min
# batch index: 1124, tot_time: 11.044min
# batch index: 1125, tot_time: 11.053min
# batch index: 1126, tot_time: 11.063min
# batch index: 1127, tot_time: 11.073min
# batch index: 1128, tot_time: 11.083min
# batch index: 1129, tot_time: 11.092min
# batch index: 1130, tot_time: 11.102min
# batch index: 1131, tot_time: 11.112min
# batch index: 1132, tot_time: 11.122min
# batch index: 1133, tot_time: 11.132min
# batch index: 1134, tot_time: 11.142min
# batch index: 1135, tot_time: 11.152min
# batch index: 1136, tot_time: 11.162min
# batch index: 1137, tot_time: 11.172min
# batch index: 1138, tot_time: 11.181min
# batch index: 1139, tot_time: 11.191min
# batch index: 1140, tot_time: 11.201min
# batch index: 1141, tot_time: 11.211min
# batch index: 1142, tot_time: 11.220min
# batch index: 1143, tot_time: 11.230min
# batch index: 1144, tot_time: 11.240min
# batch index: 1145, tot_time: 11.250min
# batch index: 1146, tot_time: 11.259min
# batch index: 1147, tot_time: 11.269min
# batch index: 1148, tot_time: 11.279min
# batch index: 1149, tot_time: 11.289min
# batch index: 1150, tot_time: 11.298min
# batch index: 1151, tot_time: 11.308min
# batch index: 1152, tot_time: 11.318min
# batch index: 1153, tot_time: 11.328min
# batch index: 1154, tot_time: 11.338min
# batch index: 1155, tot_time: 11.348min
# batch index: 1156, tot_time: 11.358min
# batch index: 1157, tot_time: 11.368min
# batch index: 1158, tot_time: 11.377min
# batch index: 1159, tot_time: 11.387min
# batch index: 1160, tot_time: 11.397min
# batch index: 1161, tot_time: 11.406min
# batch index: 1162, tot_time: 11.416min
# batch index: 1163, tot_time: 11.426min
# batch index: 1164, tot_time: 11.436min
# batch index: 1165, tot_time: 11.446min
# batch index: 1166, tot_time: 11.455min
# batch index: 1167, tot_time: 11.465min
# batch index: 1168, tot_time: 11.475min
# batch index: 1169, tot_time: 11.485min
# batch index: 1170, tot_time: 11.494min
# batch index: 1171, tot_time: 11.504min
# batch index: 1172, tot_time: 11.514min
# batch index: 1173, tot_time: 11.524min
# batch index: 1174, tot_time: 11.534min
# batch index: 1175, tot_time: 11.544min
# batch index: 1176, tot_time: 11.554min
# batch index: 1177, tot_time: 11.564min
# batch index: 1178, tot_time: 11.574min
# batch index: 1179, tot_time: 11.583min
# batch index: 1180, tot_time: 11.593min
# batch index: 1181, tot_time: 11.603min
# batch index: 1182, tot_time: 11.613min
# batch index: 1183, tot_time: 11.622min
# batch index: 1184, tot_time: 11.632min
# batch index: 1185, tot_time: 11.642min
# batch index: 1186, tot_time: 11.652min
# batch index: 1187, tot_time: 11.661min
# batch index: 1188, tot_time: 11.671min
# batch index: 1189, tot_time: 11.681min
# batch index: 1190, tot_time: 11.691min
# batch index: 1191, tot_time: 11.701min
# batch index: 1192, tot_time: 11.710min
# batch index: 1193, tot_time: 11.720min
# batch index: 1194, tot_time: 11.730min
# batch index: 1195, tot_time: 11.740min
# batch index: 1196, tot_time: 11.750min
# batch index: 1197, tot_time: 11.760min
# batch index: 1198, tot_time: 11.770min
# batch index: 1199, tot_time: 11.780min
# batch index: 1200, tot_time: 11.789min
# batch index: 1201, tot_time: 11.799min
# batch index: 1202, tot_time: 11.809min
# batch index: 1203, tot_time: 11.819min
# batch index: 1204, tot_time: 11.828min
# batch index: 1205, tot_time: 11.838min
# batch index: 1206, tot_time: 11.848min
# batch index: 1207, tot_time: 11.858min
# batch index: 1208, tot_time: 11.867min
# batch index: 1209, tot_time: 11.877min
# batch index: 1210, tot_time: 11.887min
# batch index: 1211, tot_time: 11.897min
# batch index: 1212, tot_time: 11.906min
# batch index: 1213, tot_time: 11.916min
# batch index: 1214, tot_time: 11.926min
# batch index: 1215, tot_time: 11.936min
# batch index: 1216, tot_time: 11.946min
# batch index: 1217, tot_time: 11.956min
# batch index: 1218, tot_time: 11.966min
# batch index: 1219, tot_time: 11.976min
# batch index: 1220, tot_time: 11.986min
# batch index: 1221, tot_time: 11.995min
# batch index: 1222, tot_time: 12.005min
# batch index: 1223, tot_time: 12.015min
# batch index: 1224, tot_time: 12.024min
# batch index: 1225, tot_time: 12.034min
# batch index: 1226, tot_time: 12.044min
# batch index: 1227, tot_time: 12.054min
# batch index: 1228, tot_time: 12.064min
# batch index: 1229, tot_time: 12.073min
# batch index: 1230, tot_time: 12.083min
# batch index: 1231, tot_time: 12.093min
# batch index: 1232, tot_time: 12.103min
# batch index: 1233, tot_time: 12.112min
# batch index: 1234, tot_time: 12.122min
# batch index: 1235, tot_time: 12.132min
# batch index: 1236, tot_time: 12.142min
# batch index: 1237, tot_time: 12.152min
# batch index: 1238, tot_time: 12.162min
# batch index: 1239, tot_time: 12.172min
# batch index: 1240, tot_time: 12.182min
# batch index: 1241, tot_time: 12.192min
# batch index: 1242, tot_time: 12.201min
# batch index: 1243, tot_time: 12.211min
# batch index: 1244, tot_time: 12.221min
# batch index: 1245, tot_time: 12.231min
# batch index: 1246, tot_time: 12.240min
# batch index: 1247, tot_time: 12.250min
# batch index: 1248, tot_time: 12.260min
# batch index: 1249, tot_time: 12.269min
# batch index: 1250, tot_time: 12.279min
# batch index: 1251, tot_time: 12.289min
# batch index: 1252, tot_time: 12.299min
# batch index: 1253, tot_time: 12.308min
# batch index: 1254, tot_time: 12.318min
# batch index: 1255, tot_time: 12.328min
# batch index: 1256, tot_time: 12.338min
# batch index: 1257, tot_time: 12.348min
# batch index: 1258, tot_time: 12.358min
# batch index: 1259, tot_time: 12.368min
# batch index: 1260, tot_time: 12.378min
# batch index: 1261, tot_time: 12.388min
# batch index: 1262, tot_time: 12.397min
# batch index: 1263, tot_time: 12.407min
# batch index: 1264, tot_time: 12.417min
# batch index: 1265, tot_time: 12.427min
# batch index: 1266, tot_time: 12.436min
# batch index: 1267, tot_time: 12.446min
# batch index: 1268, tot_time: 12.456min
# batch index: 1269, tot_time: 12.466min
# batch index: 1270, tot_time: 12.475min
# batch index: 1271, tot_time: 12.485min
# batch index: 1272, tot_time: 12.495min
# batch index: 1273, tot_time: 12.505min
# batch index: 1274, tot_time: 12.514min
# batch index: 1275, tot_time: 12.524min
# batch index: 1276, tot_time: 12.534min
# batch index: 1277, tot_time: 12.544min
# batch index: 1278, tot_time: 12.554min
# batch index: 1279, tot_time: 12.564min
# batch index: 1280, tot_time: 12.574min
# batch index: 1281, tot_time: 12.584min
# batch index: 1282, tot_time: 12.593min
# batch index: 1283, tot_time: 12.603min
# batch index: 1284, tot_time: 12.613min
# ...
# batch index: 1590, tot_time: 15.620min
# batch index: 1591, tot_time: 15.630min
# batch index: 1592, tot_time: 15.640min
# batch index: 1593, tot_time: 15.650min
# batch index: 1594, tot_time: 15.659min
# batch index: 1595, tot_time: 15.669min
# batch index: 1596, tot_time: 15.679min
# batch index: 1597, tot_time: 15.689min
# batch index: 1598, tot_time: 15.698min
# batch index: 1599, tot_time: 15.708min
# batch index: 1600, tot_time: 15.718min
# batch index: 1601, tot_time: 15.728min
# batch index: 1602, tot_time: 15.738min
# batch index: 1603, tot_time: 15.748min
# batch index: 1604, tot_time: 15.758min
# batch index: 1605, tot_time: 15.768min
# batch index: 1606, tot_time: 15.778min
# batch index: 1607, tot_time: 15.788min
# batch index: 1608, tot_time: 15.797min
# batch index: 1609, tot_time: 15.807min
# batch index: 1610, tot_time: 15.817min
# batch index: 1611, tot_time: 15.826min
# batch index: 1612, tot_time: 15.836min
# batch index: 1613, tot_time: 15.846min
# batch index: 1614, tot_time: 15.856min
# batch index: 1615, tot_time: 15.866min
# batch index: 1616, tot_time: 15.875min
# batch index: 1617, tot_time: 15.885min
# batch index: 1618, tot_time: 15.895min
# batch index: 1619, tot_time: 15.905min
# batch index: 1620, tot_time: 15.914min
# batch index: 1621, tot_time: 15.924min
# batch index: 1622, tot_time: 15.934min
# batch index: 1623, tot_time: 15.944min
# batch index: 1624, tot_time: 15.955min
# batch index: 1625, tot_time: 15.964min
# batch index: 1626, tot_time: 15.974min
# batch index: 1627, tot_time: 15.984min
# batch index: 1628, tot_time: 15.994min
# batch index: 1629, tot_time: 16.003min
# batch index: 1630, tot_time: 16.013min
# batch index: 1631, tot_time: 16.023min
# batch index: 1632, tot_time: 16.033min
# batch index: 1633, tot_time: 16.042min
# batch index: 1634, tot_time: 16.052min
# batch index: 1635, tot_time: 16.062min
# batch index: 1636, tot_time: 16.072min
# batch index: 1637, tot_time: 16.081min
# batch index: 1638, tot_time: 16.091min
# batch index: 1639, tot_time: 16.101min
# batch index: 1640, tot_time: 16.111min
# batch index: 1641, tot_time: 16.121min
# batch index: 1642, tot_time: 16.131min
# batch index: 1643, tot_time: 16.141min
# batch index: 1644, tot_time: 16.151min
# batch index: 1645, tot_time: 16.161min
# batch index: 1646, tot_time: 16.170min
# batch index: 1647, tot_time: 16.180min
# batch index: 1648, tot_time: 16.190min
# batch index: 1649, tot_time: 16.199min
# batch index: 1650, tot_time: 16.209min
# batch index: 1651, tot_time: 16.219min
# batch index: 1652, tot_time: 16.229min
# batch index: 1653, tot_time: 16.239min
# batch index: 1654, tot_time: 16.248min
# batch index: 1655, tot_time: 16.258min
# batch index: 1656, tot_time: 16.268min
# batch index: 1657, tot_time: 16.278min
# batch index: 1658, tot_time: 16.287min
# batch index: 1659, tot_time: 16.297min
# batch index: 1660, tot_time: 16.307min
# batch index: 1661, tot_time: 16.317min
# batch index: 1662, tot_time: 16.327min
# batch index: 1663, tot_time: 16.337min
# batch index: 1664, tot_time: 16.347min
# batch index: 1665, tot_time: 16.357min
# batch index: 1666, tot_time: 16.366min
# batch index: 1667, tot_time: 16.376min
# batch index: 1668, tot_time: 16.386min
# batch index: 1669, tot_time: 16.396min
# batch index: 1670, tot_time: 16.405min
# batch index: 1671, tot_time: 16.415min
# batch index: 1672, tot_time: 16.425min
# batch index: 1673, tot_time: 16.435min
# batch index: 1674, tot_time: 16.444min
# batch index: 1675, tot_time: 16.454min
# batch index: 1676, tot_time: 16.464min
# batch index: 1677, tot_time: 16.474min
# batch index: 1678, tot_time: 16.483min
# batch index: 1679, tot_time: 16.493min
# batch index: 1680, tot_time: 16.503min
# batch index: 1681, tot_time: 16.513min
# batch index: 1682, tot_time: 16.523min
# batch index: 1683, tot_time: 16.533min
# batch index: 1684, tot_time: 16.543min
# batch index: 1685, tot_time: 16.553min
# batch index: 1686, tot_time: 16.563min
# batch index: 1687, tot_time: 16.572min
# batch index: 1688, tot_time: 16.582min
# batch index: 1689, tot_time: 16.592min
# batch index: 1690, tot_time: 16.602min
# batch index: 1691, tot_time: 16.611min
# batch index: 1692, tot_time: 16.621min
# batch index: 1693, tot_time: 16.631min
# batch index: 1694, tot_time: 16.641min
# batch index: 1695, tot_time: 16.650min
# batch index: 1696, tot_time: 16.660min
# batch index: 1697, tot_time: 16.670min
# batch index: 1698, tot_time: 16.680min
# batch index: 1699, tot_time: 16.690min
# batch index: 1700, tot_time: 16.699min
# batch index: 1701, tot_time: 16.709min
# batch index: 1702, tot_time: 16.719min
# batch index: 1703, tot_time: 16.729min
# batch index: 1704, tot_time: 16.739min
# batch index: 1705, tot_time: 16.749min
# batch index: 1706, tot_time: 16.759min
# batch index: 1707, tot_time: 16.769min
# batch index: 1708, tot_time: 16.778min
# batch index: 1709, tot_time: 16.788min
# batch index: 1710, tot_time: 16.798min
# batch index: 1711, tot_time: 16.808min
# batch index: 1712, tot_time: 16.817min
# batch index: 1713, tot_time: 16.827min
# batch index: 1714, tot_time: 16.837min
# batch index: 1715, tot_time: 16.847min
# batch index: 1716, tot_time: 16.856min
# batch index: 1717, tot_time: 16.866min
# batch index: 1718, tot_time: 16.876min
# batch index: 1719, tot_time: 16.886min
# batch index: 1720, tot_time: 16.896min
# batch index: 1721, tot_time: 16.905min
# batch index: 1722, tot_time: 16.915min
# batch index: 1723, tot_time: 16.925min
# batch index: 1724, tot_time: 16.936min
# batch index: 1725, tot_time: 16.946min
# batch index: 1726, tot_time: 16.956min
# batch index: 1727, tot_time: 16.966min
# batch index: 1728, tot_time: 16.975min
# batch index: 1729, tot_time: 16.985min
# batch index: 1730, tot_time: 16.995min
# batch index: 1731, tot_time: 17.005min
# batch index: 1732, tot_time: 17.014min
# batch index: 1733, tot_time: 17.024min
# batch index: 1734, tot_time: 17.034min
# batch index: 1735, tot_time: 17.044min
# batch index: 1736, tot_time: 17.053min
# batch index: 1737, tot_time: 17.063min
# batch index: 1738, tot_time: 17.073min
# batch index: 1739, tot_time: 17.083min
# batch index: 1740, tot_time: 17.092min
# batch index: 1741, tot_time: 17.102min
# batch index: 1742, tot_time: 17.112min
# batch index: 1743, tot_time: 17.122min
# batch index: 1744, tot_time: 17.132min
# batch index: 1745, tot_time: 17.142min
# batch index: 1746, tot_time: 17.152min
# batch index: 1747, tot_time: 17.162min
# batch index: 1748, tot_time: 17.172min
# batch index: 1749, tot_time: 17.181min
# batch index: 1750, tot_time: 17.191min
# batch index: 1751, tot_time: 17.201min
# batch index: 1752, tot_time: 17.211min
# batch index: 1753, tot_time: 17.220min
# batch index: 1754, tot_time: 17.230min
# batch index: 1755, tot_time: 17.240min
# batch index: 1756, tot_time: 17.250min
# batch index: 1757, tot_time: 17.260min
# batch index: 1758, tot_time: 17.269min
# batch index: 1759, tot_time: 17.279min
# batch index: 1760, tot_time: 17.289min
# batch index: 1761, tot_time: 17.299min
# batch index: 1762, tot_time: 17.308min
# batch index: 1763, tot_time: 17.318min
# batch index: 1764, tot_time: 17.328min
# batch index: 1765, tot_time: 17.338min
# batch index: 1766, tot_time: 17.348min
# batch index: 1767, tot_time: 17.358min
# batch index: 1768, tot_time: 17.368min
# batch index: 1769, tot_time: 17.378min
# batch index: 1770, tot_time: 17.387min
# batch index: 1771, tot_time: 17.397min
# batch index: 1772, tot_time: 17.407min
# batch index: 1773, tot_time: 17.417min
# batch index: 1774, tot_time: 17.426min
# batch index: 1775, tot_time: 17.436min
# batch index: 1776, tot_time: 17.446min
# batch index: 1777, tot_time: 17.456min
# batch index: 1778, tot_time: 17.465min
# batch index: 1779, tot_time: 17.475min
# batch index: 1780, tot_time: 17.485min
# batch index: 1781, tot_time: 17.495min
# batch index: 1782, tot_time: 17.504min
# batch index: 1783, tot_time: 17.514min
# batch index: 1784, tot_time: 17.524min
# batch index: 1785, tot_time: 17.534min
# batch index: 1786, tot_time: 17.545min
# batch index: 1787, tot_time: 17.555min
# batch index: 1788, tot_time: 17.564min
# batch index: 1789, tot_time: 17.574min
# batch index: 1790, tot_time: 17.584min
# batch index: 1791, tot_time: 17.594min
# batch index: 1792, tot_time: 17.603min
# batch index: 1793, tot_time: 17.613min
# batch index: 1794, tot_time: 17.623min
# batch index: 1795, tot_time: 17.633min
# batch index: 1796, tot_time: 17.642min
# batch index: 1797, tot_time: 17.652min
# batch index: 1798, tot_time: 17.662min
# batch index: 1799, tot_time: 17.672min
# batch index: 1800, tot_time: 17.681min
# batch index: 1801, tot_time: 17.691min
# batch index: 1802, tot_time: 17.701min
# batch index: 1803, tot_time: 17.711min
# batch index: 1804, tot_time: 17.721min
# batch index: 1805, tot_time: 17.731min
# batch index: 1806, tot_time: 17.741min
# batch index: 1807, tot_time: 17.751min
# batch index: 1808, tot_time: 17.761min
# batch index: 1809, tot_time: 17.770min
# batch index: 1810, tot_time: 17.780min
# batch index: 1811, tot_time: 17.790min
# batch index: 1812, tot_time: 17.800min
# batch index: 1813, tot_time: 17.809min
# batch index: 1814, tot_time: 17.819min
# batch index: 1815, tot_time: 17.829min
# batch index: 1816, tot_time: 17.839min
# batch index: 1817, tot_time: 17.848min
# batch index: 1818, tot_time: 17.858min
# batch index: 1819, tot_time: 17.868min
# batch index: 1820, tot_time: 17.878min
# batch index: 1821, tot_time: 17.887min
# batch index: 1822, tot_time: 17.897min
# batch index: 1823, tot_time: 17.907min
# batch index: 1824, tot_time: 17.917min
# batch index: 1825, tot_time: 17.927min
# batch index: 1826, tot_time: 17.937min
# batch index: 1827, tot_time: 17.947min
# batch index: 1828, tot_time: 17.957min
# batch index: 1829, tot_time: 17.967min
# batch index: 1830, tot_time: 17.976min
# batch index: 1831, tot_time: 17.986min
# batch index: 1832, tot_time: 17.996min
# batch index: 1833, tot_time: 18.006min
# batch index: 1834, tot_time: 18.015min
# batch index: 1835, tot_time: 18.025min
# batch index: 1836, tot_time: 18.035min
# batch index: 1837, tot_time: 18.045min
# batch index: 1838, tot_time: 18.054min
# batch index: 1839, tot_time: 18.064min
# batch index: 1840, tot_time: 18.074min
# batch index: 1841, tot_time: 18.084min
# batch index: 1842, tot_time: 18.093min
# batch index: 1843, tot_time: 18.103min
# batch index: 1844, tot_time: 18.113min
# batch index: 1845, tot_time: 18.123min
# batch index: 1846, tot_time: 18.133min
# batch index: 1847, tot_time: 18.143min
# batch index: 1848, tot_time: 18.153min
# batch index: 1849, tot_time: 18.163min
# batch index: 1850, tot_time: 18.173min
# batch index: 1851, tot_time: 18.183min
# batch index: 1852, tot_time: 18.192min
# batch index: 1853, tot_time: 18.202min
# batch index: 1854, tot_time: 18.212min
# batch index: 1855, tot_time: 18.222min
# batch index: 1856, tot_time: 18.231min
# batch index: 1857, tot_time: 18.241min
# batch index: 1858, tot_time: 18.251min
# batch index: 1859, tot_time: 18.261min
# batch index: 1860, tot_time: 18.270min
# batch index: 1861, tot_time: 18.280min
# batch index: 1862, tot_time: 18.290min
# batch index: 1863, tot_time: 18.300min
# batch index: 1864, tot_time: 18.310min
# batch index: 1865, tot_time: 18.320min
# batch index: 1866, tot_time: 18.330min
# batch index: 1867, tot_time: 18.340min
# batch index: 1868, tot_time: 18.350min
# batch index: 1869, tot_time: 18.360min
# batch index: 1870, tot_time: 18.369min
# batch index: 1871, tot_time: 18.379min
# batch index: 1872, tot_time: 18.389min
# batch index: 1873, tot_time: 18.399min
# batch index: 1874, tot_time: 18.408min
# batch index: 1875, tot_time: 18.418min
# batch index: 1876, tot_time: 18.428min
# batch index: 1877, tot_time: 18.438min
# batch index: 1878, tot_time: 18.447min
# batch index: 1879, tot_time: 18.457min
# batch index: 1880, tot_time: 18.467min
# batch index: 1881, tot_time: 18.477min
# batch index: 1882, tot_time: 18.487min
# batch index: 1883, tot_time: 18.496min
# batch index: 1884, tot_time: 18.506min
# batch index: 1885, tot_time: 18.516min
# batch index: 1886, tot_time: 18.526min
# batch index: 1887, tot_time: 18.536min
# batch index: 1888, tot_time: 18.546min
# batch index: 1889, tot_time: 18.556min
# batch index: 1890, tot_time: 18.566min
# batch index: 1891, tot_time: 18.576min
# batch index: 1892, tot_time: 18.585min
# batch index: 1893, tot_time: 18.595min
# batch index: 1894, tot_time: 18.605min
# batch index: 1895, tot_time: 18.615min
# batch index: 1896, tot_time: 18.624min
# batch index: 1897, tot_time: 18.634min
# batch index: 1898, tot_time: 18.644min
# batch index: 1899, tot_time: 18.654min
# batch index: 1900, tot_time: 18.664min
# batch index: 1901, tot_time: 18.673min
# batch index: 1902, tot_time: 18.683min
# batch index: 1903, tot_time: 18.693min
# batch index: 1904, tot_time: 18.703min
# batch index: 1905, tot_time: 18.712min
# batch index: 1906, tot_time: 18.723min
# batch index: 1907, tot_time: 18.733min
# batch index: 1908, tot_time: 18.743min
# batch index: 1909, tot_time: 18.753min
# batch index: 1910, tot_time: 18.762min
# batch index: 1911, tot_time: 18.772min
# batch index: 1912, tot_time: 18.782min
# batch index: 1913, tot_time: 18.792min
# batch index: 1914, tot_time: 18.802min
# batch index: 1915, tot_time: 18.811min
# batch index: 1916, tot_time: 18.821min
# batch index: 1917, tot_time: 18.831min
# batch index: 1918, tot_time: 18.841min
# batch index: 1919, tot_time: 18.850min
# batch index: 1920, tot_time: 18.860min
# batch index: 1921, tot_time: 18.870min
# batch index: 1922, tot_time: 18.880min
# batch index: 1923, tot_time: 18.889min
# batch index: 1924, tot_time: 18.899min
# batch index: 1925, tot_time: 18.909min
# batch index: 1926, tot_time: 18.919min
# batch index: 1927, tot_time: 18.929min
# batch index: 1928, tot_time: 18.939min
# batch index: 1929, tot_time: 18.949min
# batch index: 1930, tot_time: 18.959min
# batch index: 1931, tot_time: 18.969min
# batch index: 1932, tot_time: 18.979min
# batch index: 1933, tot_time: 18.988min
# batch index: 1934, tot_time: 18.998min
# batch index: 1935, tot_time: 19.008min
# batch index: 1936, tot_time: 19.018min
# batch index: 1937, tot_time: 19.027min
# batch index: 1938, tot_time: 19.037min
# batch index: 1939, tot_time: 19.047min
# batch index: 1940, tot_time: 19.057min
# batch index: 1941, tot_time: 19.066min
# batch index: 1942, tot_time: 19.076min
# batch index: 1943, tot_time: 19.086min
# batch index: 1944, tot_time: 19.096min
# batch index: 1945, tot_time: 19.105min
# batch index: 1946, tot_time: 19.115min
# batch index: 1947, tot_time: 19.125min
# batch index: 1948, tot_time: 19.135min
# batch index: 1949, tot_time: 19.145min
# batch index: 1950, tot_time: 19.155min
# batch index: 1951, tot_time: 19.165min
# batch index: 1952, tot_time: 19.175min
# batch index: 1953, tot_time: 19.184min
# batch index: 1954, tot_time: 19.194min
# batch index: 1955, tot_time: 19.204min
# batch index: 1956, tot_time: 19.214min
# batch index: 1957, tot_time: 19.223min
# batch index: 1958, tot_time: 19.233min
# batch index: 1959, tot_time: 19.243min
# batch index: 1960, tot_time: 19.253min
# batch index: 1961, tot_time: 19.262min
# batch index: 1962, tot_time: 19.272min
# batch index: 1963, tot_time: 19.282min
# batch index: 1964, tot_time: 19.292min
# batch index: 1965, tot_time: 19.301min
# batch index: 1966, tot_time: 19.311min
# batch index: 1967, tot_time: 19.321min
# batch index: 1968, tot_time: 19.332min
# batch index: 1969, tot_time: 19.342min
# batch index: 1970, tot_time: 19.352min
# batch index: 1971, tot_time: 19.361min
# batch index: 1972, tot_time: 19.371min
# batch index: 1973, tot_time: 19.381min
# batch index: 1974, tot_time: 19.391min
# batch index: 1975, tot_time: 19.400min
# batch index: 1976, tot_time: 19.410min
# batch index: 1977, tot_time: 19.420min
# batch index: 1978, tot_time: 19.430min
# batch index: 1979, tot_time: 19.439min
# batch index: 1980, tot_time: 19.449min
# batch index: 1981, tot_time: 19.459min
# batch index: 1982, tot_time: 19.469min
# batch index: 1983, tot_time: 19.478min
# batch index: 1984, tot_time: 19.488min
# batch index: 1985, tot_time: 19.498min
# batch index: 1986, tot_time: 19.508min
# batch index: 1987, tot_time: 19.518min
# batch index: 1988, tot_time: 19.528min
# batch index: 1989, tot_time: 19.538min
# batch index: 1990, tot_time: 19.548min
# batch index: 1991, tot_time: 19.558min
# batch index: 1992, tot_time: 19.567min
# batch index: 1993, tot_time: 19.577min
# batch index: 1994, tot_time: 19.587min
# batch index: 1995, tot_time: 19.597min
# batch index: 1996, tot_time: 19.607min
# batch index: 1997, tot_time: 19.616min
# batch index: 1998, tot_time: 19.626min
# batch index: 1999, tot_time: 19.636min

# %%
###################
# Write result file
###################
nb_TSPs = args.nb_batch_eval* args.bsz
file_name = "beamsearch-nb_nodes{}".format(args.nb_nodes) + "-nb_TSPs{}".format(nb_TSPs) + "-B{}".format(B) + ".txt"
file = open(file_name,"w",1)
mystring = '\nnb_nodes: {:d}, nb_TSPs: {:d}, B: {:d}, L_greedy: {:.6f}, L_concorde: {:.5f}, L_beamsearch: {:.5f}, \
gap_greedy(%): {:.5f}, gap_beamsearch(%): {:.5f}, scores_greedy: {:.5f}, scores_beamsearch: {:.5f}, tot_time: {:.4f}min, \
tot_time: {:.3f}hr, mean_time: {:.3f}sec'.format(args.nb_nodes, nb_TSPs, B, mean_tour_length_greedy, L_concorde, \
                                 mean_tour_length_beamsearch, 100*gap_greedy, 100*gap_beamsearch, mean_scores_greedy, \
                                 mean_scores_beamsearch, tot_time/60, tot_time/3600, tot_time/nb_TSPs)
print(mystring)
file.write(mystring)
file.close()
# Out:
# nb_nodes: 50, nb_TSPs: 10000, B: 500, L_greedy: 0.000000, L_concorde: 4270.64893, L_beamsearch: 17451.46341, gap_greedy(%): 0.00000, gap_beamsearch(%): 309.16174, scores_greedy: 0.00000, scores_beamsearch: -49.32236, tot_time: 19.6458min, tot_time: 0.327hr, mean_time: 0.118sec

# %% [markdown]
# # 画图

# %%
pip show networkx
# Out:
# Name: networkx
# Version: 3.4.2
# Summary: Python package for creating and manipulating graphs and networks
# Home-page: https://networkx.org/
# Author:
# Author-email: Aric Hagberg <hagberg@lanl.gov>
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires:
# Required-by: hyperopt, nx-cugraph-cu12, python-louvain, scikit-image, spanner-graph-notebook, torch

# %%
pip show pyconcorde
# Out:
# Name: pyconcorde
# Version: 0.1.0
# Summary: Cython wrappers for the Concorde TSP library
# Home-page: https://github.com/jvkersch/pyconcorde
# Author: Joris Vankerschaver
# Author-email: joris.vankerschaver@gmail.com
# License: BSD
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: cython, numpy, tsplib95
# Required-by:

# %%
from pyconcorde import TSPSolver
import numpy as np

# 生成随机坐标
x = np.random.rand(5)
y = np.random.rand(5)

# 调用 Concorde 求解
solver = TSPSolver.from_data(x, y, norm="GEO")
solution = solver.solve()
print("最优路径:", solution.tour)
# Out:
# 最优路径: [0 4 2 1 3]

# %%
bsz = 4

nb_nodes = 50; B = 2500; greedy = False; beamsearch = True
# nb_nodes = 100; B = 100
# nb_nodes = 100; B = 1000
# nb_nodes = 100; B = 3000
# nb_nodes = 200; B = 100
# nb_nodes = 200; B = 1000

x = torch.rand(bsz, nb_nodes, 2)
x = x.to(device)


with torch.no_grad():
    tours_greedy, tours_beamsearch, scores_greedy, scores_beamsearch = model_baseline(x, B, True, True)
    # greedy
    L_greedy = compute_tour_length(x, tours_greedy)
    mean_tour_length_greedy = L_greedy.mean().item()
    mean_scores_greedy = scores_greedy.mean().item()
    # beamsearch
    tours_beamsearch = tours_beamsearch.view(bsz*B, nb_nodes)
    x_beamsearch = x.repeat_interleave(B,dim=0)
    L_beamsearch = compute_tour_length(x_beamsearch, tours_beamsearch)
    L_beamsearch = L_beamsearch.view(bsz, B)
    L_beamsearch, idx_min = L_beamsearch.min(dim=1)
    tours_beamsearch = tours_beamsearch.view(bsz, B, nb_nodes)
    torch.cuda.empty_cache() # free GPU reserved memory
    print('GPU reserved mem: {:.2f}, GPU allocated mem: {:.2f}'.format(torch.cuda.memory_reserved(0)/1e9,torch.cuda.memory_allocated(0)/1e9))

print('L_greedy',L_greedy)
print('L_beamsearch',L_beamsearch)

tours = []
for b in range(bsz):
    tours.append(tours_beamsearch[b,idx_min[b],:])
tours_beamsearch = torch.stack(tours, dim=0)

#plot_tsp(x, tours_greedy, plot_concorde=True)
plot_tsp(x, tours_beamsearch, plot_concorde=True)
# Out:
# GPU reserved mem: 2.98, GPU allocated mem: 0.63
# L_greedy tensor([5.8542, 5.7472, 5.9076, 5.4299], device='cuda:0')
# L_beamsearch tensor([5.8466, 5.7235, 5.9027, 5.4275], device='cuda:0')
# L_concorde tensor([5.8466, 5.7253, 5.9076, 5.4275])
# Concorde time: 0.294sec
# gap: -0.0002844482660293579
